# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
import re
import numpy as np
import pandas as pd
import pickle
from torch.optim.lr_scheduler import StepLR

# %%
#Hyperparameter

hidden_size = 512
PAD_TOKEN = 0
SOS_TOKEN = 1
EOS_TOKEN = 2
UNK_TOKEN = 3
MAX_LENGTH = 300
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
def clean_text(text):
    if pd.isna(text): # NaN 값 처리
        return ''
    korean_pattern = r'[^ ?,.!A-Za-z0-9가-힣+]'
    korean_normalizer = re.compile(korean_pattern)
    text = text.lower()
    text = korean_normalizer.sub("", text)
    text = text.strip() # 텍스트 양 옆의 공백 제거
    
    return text

# %%
from mecab import MeCab
mecab = MeCab()

# %%
def indiceFromSentence(vocab, sentence):
    return [vocab.get(word, vocab['<UNK>']) for word in mecab.morphs(sentence)]

# %%
def tensorFromSentence(vocab, sentence):
    indice = indiceFromSentence(vocab, sentence)
    indice.append(EOS_TOKEN)
    return torch.tensor(indice, dtype=torch.long, device=device).view(-1, 1)

# %%
class EncoderLSTM(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers=2)
        
    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output, hidden = self.lstm(embedded, hidden)
        return output, hidden
    
    def initHidden(self):
        return(torch.zeros(2, 1, self.hidden_size, device=device), torch.zeros(2, 1, self.hidden_size, device=device))

# %%
class AttentionDecoderLSTM(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(AttentionDecoderLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(output_size, self.hidden_size)
        self.drop_out = nn.Dropout(0.2)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers=2) # hidden state, cell state
        self.out = nn.Linear(hidden_size, output_size)
        
    def forward(self, input, hidden, encoder_outputs):
        
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.drop_out(embedded)
        attention_weights = F.softmax(torch.bmm(encoder_outputs.unsqueeze(0), hidden[0][0].unsqueeze(2)).squeeze(2), dim=1) # batch matrix multiplication, dot product
        attention_applied = torch.bmm(attention_weights.unsqueeze(0), encoder_outputs.unsqueeze(0))
                
        new_hidden = (torch.vstack([attention_applied, attention_applied]), hidden[1])
        output, hidden = self.lstm(embedded[0].unsqueeze(0), new_hidden)
        output = self.out(output[0])
        return output, hidden, attention_weights
    
    def initHidden(self):
        return(torch.zeros(2, 1, self.hidden_size, device=device), torch.zeros(2, 1, self.hidden_size, device=device))

# %%
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()
    
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()
    
    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)
    
    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
    
    loss = 0    
    
    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] += encoder_output[0, 0]
        
    decoder_input = torch.tensor([[SOS_TOKEN]], device=device)
    decoder_hidden = encoder_hidden
    

    sentence = []
    teach_ratio = 0.5
    for di in range(target_length):
        decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
        if random.random() < teach_ratio:
            topi = target_tensor[di]
        else:
            
            topv, topi = decoder_output.topk(1)

        decoder_input = topi.squeeze().detach()
        loss += criterion(decoder_output, target_tensor[di])
        
        if decoder_input.item() == EOS_TOKEN:
            break
    #     sentence.append(idx_to_word[decoder_input.item()])
    # print(' '.join(sentence))

    loss.backward() # 역전파 
    
    encoder_optimizer.step()
    decoder_optimizer.step()
    
    return loss.item() / target_length

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, learning_rate=0.01):
    print_loss_total = 0
    
    scheduler_encoder = StepLR(encoder_optimizer, step_size=10, gamma=0.1) # 10번마다 학습률이 10%로 줄인다.
    scheduler_decoder = StepLR(decoder_optimizer, step_size=10, gamma=0.1)
    min_loss = 1000000
    
    for iter in range(1, n_iters+1):
        training_pair = random.choice(pairs) # input - target pair
        input_tensor = tensorFromSentence(word_to_idx, training_pair[0]).to(device)
        target_tensor = tensorFromSentence(word_to_idx, training_pair[1]).to(device)
        
        loss = train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        
        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print(f'Iteration : {iter}, Loss : {print_loss_avg: .4f}')
            print_loss_total = 0
            
            if min_loss > print_loss_avg:
                torch.save(encoder.state_dict(), './encoder_seq2seq_attention_dot_' + str(iter) + '.pth')
                torch.save(decoder.state_dict(), '/decoder_seq2seq_attention_dot_' + str(iter) + '.pth')
                min_loss = print_loss_avg
            
            scheduler_encoder.step()
            scheduler_decoder.step()

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(word_to_idx, sentence).to(device)
        input_length = input_tensor.size(0)
        encoder_hidden = encoder.initHidden()
        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
        
        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]
            
        decoder_input = torch.tensor([[SOS_TOKEN]], device=device)
        decoder_hidden = encoder_hidden
        decoded_words = [] # output sentence
        
        decoder_attentions = torch.zeros(max_length, max_length)
        
        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_TOKEN:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(idx_to_word[topi.item()]) # 최종 아웃풋의 index
            
            decoder_input = topi.squeeze().detach()
        
        meaningful_words = [word for word in decoded_words if word not in ('<EOS>', '<UNK>')]
        final_output = ' '.join(meaningful_words)
        return final_output

# %%
def chat(encoder, decoder, max_length=MAX_LENGTH):
    print("Let's chat (type 'bye' to exit)")
    while True:
        input_sentence = input(">>")
        if input_sentence == 'bye':
            break
        output_sentence = evaluate(encoder, decoder, input_sentence)
        print('<', output_sentence)

# %%
# load data and preprocessing
df = pd.read_csv('./dementia_fix.csv', sep=',', names=['Question', 'Intention', 'Answer'], skiprows=1)
df['Encoder Inputs'] = df['Question'].apply(clean_text)
df['Decoder Inputs'] = df['Answer'].apply(clean_text)

# %%
df['Encoder Inputs']
# Out:
# 0       알츠하이머병의 원인으로 매일 소주를 섭취하는 것이 언급되고 있는데, 이에 대한 근거...
# 1                          알츠하이머병이라는 질병은 유전적 영향을 받는 것인가요?
# 2                      알츠하이머병의 발생 원인에 대한 연구나 발견이 진행 중인가요?
# 3               알츠하이머병의 발병과 관련하여 뇌의 노화로 인한 증상과 원인을 알려주세요.
# 4                     알츠하이머병의 원인과 관련된 연구 결과가 있을까요? 알려주세요.
#                               ...
# 6618                          치매 치료에는 어떤 운동이나 작업이 효과적일까요?
# 6619     치매 치료의 결과와 과정을 상세히 설명해주세요. 치매 치료의 효과는 어떻게 나타날까요?
# 6620                       치매를 치료하기 위해 어떤 치료 방법들이 효과적일까요?
# 6621                         치매 치료를 위해 어떤 약물이 사용될 수 있을까요?
# 6622                          치매 치료를 위해 어떤 전문가와 협력해야 할까요?
# Name: Encoder Inputs, Length: 6623, dtype: object

# %%
df['Decoder Inputs']
# Out:
# 0       알츠하이머병의 정확한 원인은 아직 밝혀지지 않았지만, 연구들이 알츠하이머병의 발병 ...
# 1       알츠하이머병은 현재까지 완전한 원인이 밝혀지지 않았습니다.알츠하이머병은 아직 완전히...
# 2       알츠하이머병은 치매를 일으키는 가장 흔한 퇴행성 뇌질환으로, 1907년 독일 의사 ...
# 3       알츠하이머병은 현재까지 그 발병 원인에 대한 완벽한 해명은 아직 이루어지지 않았습니...
# 4       알츠하이머병은 복잡한 질환으로, 아직도 원인이 완전히 밝혀진 것은 아닙니다. 그러나...
#                               ...
# 6618    치매는 노인들에게 주로 발생하는 뇌질환으로, 원인과 치료 방법은 아직 완전히 밝혀진...
# 6619    치매는 일상 생활을 수행하는 능력을 심각하게 손상시키는 질환으로, 후천성 치매와 노...
# 6620    치매는 노화로 인해 기억력과 지능을 점차적으로 잃는 질병으로, 알츠하이머병이 주요한...
# 6621    알츠하이머병은 뇌에 변화가 생겨서 인지 기능에 장애가 생기는 신경퇴행성 질환입니다....
# 6622    치매는 현재까지 완전한 치료가 불가능한 치매입니다. 치매는 다양한 원인에 의해 발생...
# Name: Decoder Inputs, Length: 6623, dtype: object

# %%
input_sentence = [sentence for sentence in df['Encoder Inputs']]
output_sentence = [sentence + "<EOS>" for sentence in df['Decoder Inputs']]

# %%
input_sentence[0:5]
# Out:
# ['알츠하이머병의 원인으로 매일 소주를 섭취하는 것이 언급되고 있는데, 이에 대한 근거가 있는지 알려주세요.',
#  '알츠하이머병이라는 질병은 유전적 영향을 받는 것인가요?',
#  '알츠하이머병의 발생 원인에 대한 연구나 발견이 진행 중인가요?',
#  '알츠하이머병의 발병과 관련하여 뇌의 노화로 인한 증상과 원인을 알려주세요.',
#  '알츠하이머병의 원인과 관련된 연구 결과가 있을까요? 알려주세요.']

# %%
output_sentence[0:5]
# Out:
# ['알츠하이머병의 정확한 원인은 아직 밝혀지지 않았지만, 연구들이 알츠하이머병의 발병 기전에 대해 논의하고 있습니다. 일부 연구에 따르면, 유전적인 요소와 뇌의 기능 손상이 관련되어 있다고 알려져 있습니다.알츠하이머병은 아밀로이드 베타 단백질과 타우 단백질의 과도한 생성, 뇌 세포의 비정상적인 활동, 뇌 조직의 변화로 인해 발생하는 것으로 생각되고 있습니다. 이러한 변화가 알츠하이머병의 발병 위험을 증가시키고, 병의 진행을 가속화시킨다는 것입니다.알츠하이머병의 발병과 관련된 위험 요소에 대해서는 더 많은 연구와 조사가 필요합니다. 더 많은 연구와 자료 수집을 통해 알츠하이머병에 대한 더 많은 이해와 예방 방법이 개발될 것으로 기대됩니다.<EOS>',
#  '알츠하이머병은 현재까지 완전한 원인이 밝혀지지 않았습니다.알츠하이머병은 아직 완전히 이해되지 않았지만, 연구 결과에 따르면 유전적인 요소와 다양한 환경적인 요인이 이 질환을 일으키는 역할을 한다고 알려져 있습니다. 특히, 아밀로이드 베타 단백질의 비정상적인 축적이 알츠하이머병과 관련이 있는 것으로 알려져 있습니다. 이 외에도 나이, 노화, 고혈압, 당뇨병, 그리고 흡연 등과 같은 다른 요인들도 알츠하이머병 발병과 연관성이 있을 수 있습니다.더 많은 연구와 조사를 통해 알츠하이머병의 원인을 파악하고 예방 방법을 개발할 필요가 있습니다.<EOS>',
#  '알츠하이머병은 치매를 일으키는 가장 흔한 퇴행성 뇌질환으로, 1907년 독일 의사 알로이스 알츠하이머에 의해 처음으로 보고되었습니다. 이 질환의 원인에 대해서는 현재까지 명확한 답은 없으나, 치매 발생의 위험 요소와 관련하여 몇 가지 위험 요인이 알려져 있습니다.일반적으로, 가장 잘 알려진 요인 중 하나는 고령입니다. 고령은 치매의 발병 위험을 증가시키는 가장 큰 위험 요소로 알려져 있습니다. 또한, 가족력이 있는 경우 알츠하이머병 발생 위험이 높아집니다. 연구에 따르면, 조발성 가족성 알츠하이머병은 주로 65세 이전에 발생하는 반면, 노인성 알츠하이머병은 주로 65세 이후에 발생한다고 합니다. 이 외에도, 여성들은 65세 이후에 더 높은 위험에 노출되는 경향이 있으며, 우울증이나 두부 손상과 같은 선행 요인도 알츠하이머병 발병 위험을 증가시킬 수 있습니다.또한, 고혈압, 당뇨, 고지혈증, 비만과 같은 심혈관 질환도 알츠하이머병의 발병 위험을 증가시킬 수 있습니다. 이 외에도, 다양한 질병들도 알츠하이머병 발병 위험을 증가시킬 수 있습니다. 하지만 아직까지 특정한 원인에 대해 명확한 답변은 없습니다. 알츠하이머병의 정확한 원인은 아직까지 연구 중이지만, 치매와 관련된 위험 요소들과 함께 유전적 요소, 환경적 요소들이 복합적으로 작용하여 발병한다는 것이 유력한 가설로 여겨집니다.<EOS>',
#  '알츠하이머병은 현재까지 그 발병 원인에 대한 완벽한 해명은 아직 이루어지지 않았습니다.알츠하이머병의 발병 기전은 아직 정확하게 밝혀지지 않았지만, 유전적인 요인과 다양한 환경적 요소들이 서로 작용하여 발생한다는 가설이 제시되고 있습니다. 대표적으로 아밀로이드 베타 단백질의 쌓임과 신경세포의 손상이 알츠하이머병의 발병 원인으로 알려져 있으며, 아밀로이드 베타 단백질의 침착이 발생과 관련이 있는 것으로 추정됩니다. 또한, 알츠하이머병은 신경세포 사이의 신호 전송과 관련된 여러 가지 경로에서 뇌 손상이 일어나기 때문에 다른 뇌질환과도 연관되어 있을 수 있습니다. 그러나 이러한 환경적 요소들과 유전적 요인들은 아직 완전히 규명되지는 않았으며, 개인의 특성이나 환경적 요소에 따라 발병 가능성이 달라질 수 있습니다.알츠하이머병은 아직까지 정확한 원인이 밝혀지지 않았지만, 유전적 요인과 다양한 환경적 요소들이 복합적으로 작용하여 발병한다는 점은 분명한 사실입니다. 추가적인 연구가 필요하며, 예방 및 치료 방법을 개발하기 위해 노력이 필요합니다.<EOS>',
#  '알츠하이머병은 복잡한 질환으로, 아직도 원인이 완전히 밝혀진 것은 아닙니다. 그러나 연구결과에 따르면, 알츠하이머병은 단일 원인으로 발생하지 않고 여러 요인들이 복합적으로 작용하는 것으로 알려져 있습니다. 알츠하이머병은 21번 염색체에 위치한 21번 염색체의 이상, 14번 염색체의 ps1 유전자 변이나 19번 염색체의 ps2 유전자 변이도 주요 원인으로 보고되고 있습니다. 또한 고령, 다운증후군, 저학력, 가족력, 심혈관 질환 등 다양한 위험 요인이 있습니다. 더불어 노화와 더불어 콜린 계통의 활성화도 감소되는 것으로 알려져 있습니다. 알츠하이머병은 진행성 치매로, 초기에는 주로 기억력 저하와 인식력의 감퇴가 나타납니다. 그러나 병이 진행됨에 따라 일상생활 기능 손상과 판단력 저하가 더욱 심해집니다. 치매 환자는 말이나 행동이 느렸을 뿐 아니라 최근 기억력 상실과 언어 장애가 자주 동반됩니다. 수면 이상, 성격 변화, 우울증, 망상, 환각, 정신증 등의 정신 증상도 나타날 수 있습니다.알츠하이머병은 아직 정확한 원인은 밝혀지지 않았지만, 유전적인 요소와 환경적인 요인이 복합적으로 작용하여 발병할 것으로 예상됩니다. 유전적인 위험 요소가 있는 경우 병이 발현되기 쉬울 수 있지만, 그렇지 않은 경우에도 발병할 가능성이 높습니다. 알츠하이머병은 발병 과정에서 다양한 위험 요인들이 함께 작용하는 것으로 알려져 있습니다. 노화, 다운증후군, 저학력, 가족력, 심혈관 질환 등이 알츠하이머병의 위험 요소로 알려져 있으며, 노화와 더불어 콜린 계통의 손상은 진행을 가속화시킬 수 있습니다. 알츠하이머병이 가장 일찍 인지되는 이유는 최근 일에 대한 기억력 저하뿐 아니라 최근의 사건들에 대한 기억력까지 저하된다는 점입니다. 다른 정신 증상으로는 망상, 환각, 불안, 공격성 증가, 우울증 등이 동반될 수 있습니다.알츠하이머병은 아직 정확한 원인을 찾기 어려운 질병입니다. 유전적인 요소와 환경적인 요인들이 상호 작용하여 발병하는 것으로 알려져 있으며, 다양한 위험 요인들이 서로 연결되어 있습니다. 이 질병은 알츠하이머병이 가장 일찍 인지되는 이유는 최근 일에 대한 기억력 저하뿐 아니라 최근의 사건들에 대한 기억력까지 저하된다는 점입니다. 따라서, 알츠하이머병의 위험 요인을 최소화하고 건강한 라이프스타일을 유지하는 것이 중요합니다. 건강한 식습관과 꾸준한 신체 운동, 인지행동 요법을 통해 삶의 질을 개선하는 것이 예방에 도움이 됩니다.<EOS>']

# %%
# 단어 사전 생성
all_word = set(' '.join(df['Encoder Inputs'].tolist() + df['Decoder Inputs'].tolist()).split())
vocab = {'<PAD>': PAD_TOKEN, '<SOS>': SOS_TOKEN, '<EOS>': EOS_TOKEN, '<UNK>': UNK_TOKEN}
vocab.update({word: i+4 for i, word in enumerate(all_word)})
vocab_size = len(vocab)

# with open('./dataset/vocab.pkl', 'wb') as f:
#     pickle.dump(vocab, f)

# %%
with open('./dataset/word_to_idx.pkl', 'rb') as f:
    vocab = pickle.load(f)

# %%
vocab
# Out:
# {'<PAD>': 0,
#  '<SOS>': 1,
#  '<EOS>': 2,
#  '<UNK>': 3,
#  '알츠하이머병': 4,
#  '의': 5,
#  '원인': 6,
#  '으로': 7,
#  '매일': 8,
#  '소주': 9,
#  '를': 10,
#  '섭취': 11,
#  '하': 12,
#  '는': 13,
#  '것': 14,
#  '이': 15,
#  '언급': 16,
#  '되': 17,
#  '고': 18,
#  '있': 19,
#  '는데': 20,
#  ',': 21,
#  '에': 22,
#  '대한': 23,
#  '근거': 24,
#  '가': 25,
#  '는지': 26,
#  '알려': 27,
#  '주': 28,
#  '세요': 29,
#  '.': 30,
#  '라는': 31,
#  '질병': 32,
#  '은': 33,
#  '유전': 34,
#  '적': 35,
#  '영향': 36,
#  '을': 37,
#  '받': 38,
#  '인가요': 39,
#  '?': 40,
#  '발생': 41,
#  '연구': 42,
#  '나': 43,
#  '발견': 44,
#  '진행': 45,
#  '중': 46,
#  '발병': 47,
#  '과': 48,
#  '관련': 49,
#  '여': 50,
#  '뇌': 51,
#  '노화': 52,
#  '로': 53,
#  '인한': 54,
#  '증상': 55,
#  '된': 56,
#  '결과': 57,
#  '을까요': 58,
#  '무엇': 59,
#  '주요': 60,
#  '예방': 61,
#  '위해': 62,
#  '한': 63,
#  '병': 64,
#  '씩': 65,
#  '권장': 66,
#  '이유': 67,
#  '다른': 68,
#  '들': 69,
#  '대해': 70,
#  '데': 71,
#  '미치': 72,
#  '요인': 73,
#  '어떤': 74,
#  '나요': 75,
#  '치매': 76,
#  '사이': 77,
#  '어떠': 78,
#  '연관': 79,
#  '성': 80,
#  '하나': 81,
#  '인': 82,
#  '대해서': 83,
#  '자세히': 84,
#  '가족력': 85,
#  '이외': 86,
#  '상세': 87,
#  '게': 88,
#  '설명': 89,
#  '해': 90,
#  '그': 91,
#  '따른': 92,
#  '알': 93,
#  '싶': 94,
#  '어요': 95,
#  '과정': 96,
#  '에서': 97,
#  '가장': 98,
#  '문제': 99,
#  '될': 100,
#  '수': 101,
#  '감염': 102,
#  '균': 103,
#  '정의': 104,
#  '와': 105,
#  '특징': 106,
#  '30': 107,
#  '대': 108,
#  '더': 109,
#  '쉽': 110,
#  '찾아볼': 111,
#  '외': 112,
#  '생기': 113,
#  '현상': 114,
#  '차이점': 115,
#  '알려져': 116,
#  '일어나': 117,
#  '큰': 118,
#  '역할': 119,
#  '마시': 120,
#  '란': 121,
#  '습니다': 122,
#  '확인': 123,
#  '기': 124,
#  '의료': 125,
#  '기관': 126,
#  '방문': 127,
#  '해야': 128,
#  '자세': 129,
#  '듣': 130,
#  '중요': 131,
#  '사항': 132,
#  '흔히': 133,
#  '위한': 134,
#  '조치': 135,
#  '예방법': 136,
#  '나이': 137,
#  '젊': 138,
#  '사람': 139,
#  '에게': 140,
#  '도': 141,
#  '많이': 142,
#  '나타나': 143,
#  '알려진': 144,
#  '존재': 145,
#  '40': 146,
#  '세': 147,
#  '인데': 148,
#  '의해': 149,
#  '할': 150,
#  '일으키': 151,
#  '최신': 152,
#  '요소': 153,
#  '걸리': 154,
#  '이나': 155,
#  '신체': 156,
#  '변화': 157,
#  '주의': 158,
#  '가설': 159,
#  '실': 160,
#  '실험': 161,
#  '진단': 162,
#  '검사': 163,
#  '검토': 164,
#  '할까요': 165,
#  '내': 166,
#  '머리': 167,
#  '속': 168,
#  '지우개': 169,
#  '영화': 170,
#  '나오': 171,
#  '일까요': 172,
#  '위해서': 173,
#  '필요': 174,
#  '한가요': 175,
#  '거나': 176,
#  '관리': 177,
#  '취해야': 178,
#  '인지': 179,
#  '관계': 180,
#  '걸릴': 181,
#  '정보': 182,
#  '퇴행': 183,
#  '최근': 184,
#  '었': 185,
#  '방법': 186,
#  '사용': 187,
#  '추가': 188,
#  '종류': 189,
#  '인자': 190,
#  '효과': 191,
#  '기억': 192,
#  '장애': 193,
#  '언어': 194,
#  '서로': 195,
#  '다른가요': 196,
#  '한다면': 197,
#  '공통점': 198,
#  '정확': 199,
#  '의료진': 200,
#  '제공': 201,
#  '질환': 202,
#  '어': 203,
#  '주장': 204,
#  '점': 205,
#  '관여': 206,
#  '유사': 207,
#  '면서': 208,
#  '건가요': 209,
#  '노인': 210,
#  '에게서': 211,
#  '주로': 212,
#  '작용': 213,
#  '자주': 214,
#  '았': 215,
#  '어떻': 216,
#  '궁금': 217,
#  '합니다': 218,
#  '동향': 219,
#  '좋': 220,
#  '비교': 221,
#  '해서': 222,
#  '수단': 223,
#  '연령': 224,
#  '볼': 225,
#  '이해': 226,
#  '도움': 227,
#  '만': 228,
#  '미칠': 229,
#  '왜': 230,
#  '관한': 231,
#  '기본': 232,
#  '차이': 233,
#  '이란': 234,
#  '의미': 235,
#  '용어': 236,
#  '인해': 237,
#  '핵심': 238,
#  '파킨슨병': 239,
#  '가지': 240,
#  '특성': 241,
#  '우리': 242,
#  '아': 243,
#  '그리고': 244,
#  '어떻게': 245,
#  '정확히': 246,
#  '기준': 247,
#  '같': 248,
#  '갖': 249,
#  '신경': 250,
#  '면': 251,
#  '구분': 252,
#  '다른지': 253,
#  '명칭': 254,
#  '치료': 255,
#  '보이': 256,
#  '구별': 257,
#  '될까요': 258,
#  '노망': 259,
#  '병인': 260,
#  '경우': 261,
#  '말': 262,
#  '나타날': 263,
#  '비슷': 264,
#  '라고': 265,
#  '식': 266,
#  '동일': 267,
#  '방식': 268,
#  '증세': 269,
#  '맞': 270,
#  '유발': 271,
#  '형태': 272,
#  '내용': 273,
#  '기억력': 274,
#  '감퇴': 275,
#  '단어': 276,
#  '잘': 277,
#  '떠오르': 278,
#  '지': 279,
#  '않': 280,
#  '일상': 281,
#  '생활': 282,
#  '환자': 283,
#  '특히': 284,
#  '대표': 285,
#  '심각': 286,
#  '다면': 287,
#  '초기': 288,
#  '단계': 289,
#  '상': 290,
#  '실증': 291,
#  '아니': 292,
#  '라': 293,
#  '걸렸': 294,
#  '때': 295,
#  '일반인': 296,
#  '흔한': 297,
#  '얼마나': 298,
#  '시간': 299,
#  '가까운': 300,
#  '저하': 301,
#  '일반': 302,
#  '시': 303,
#  '할머니': 304,
#  '동반': 305,
#  '조심': 306,
#  '상실': 307,
#  '잊어버리': 308,
#  '포함': 309,
#  '먼저': 310,
#  '느끼': 311,
#  '생각': 312,
#  '못하': 313,
#  '잃': 314,
#  '해요': 315,
#  '나타날까요': 316,
#  '나타내': 317,
#  '시설': 318,
#  '어디': 319,
#  '상세히': 320,
#  '각각': 321,
#  '절차': 322,
#  '거쳐야': 323,
#  '어야': 324,
#  '느낄': 325,
#  '으려면': 326,
#  '아야': 327,
#  '의한': 328,
#  '함께': 329,
#  '예후': 330,
#  '병원': 331,
#  '의사': 332,
#  '찾': 333,
#  '이루': 334,
#  '약화': 335,
#  '판단': 336,
#  '특이': 337,
#  '부탁드립니다': 338,
#  '경험': 339,
#  '쉬운': 340,
#  '시행': 341,
#  '전문가': 342,
#  '누구': 343,
#  '보통': 344,
#  '이상': 345,
#  '떠올리': 346,
#  '혈액': 347,
#  '중증': 348,
#  '정하': 349,
#  '알츠하이머': 350,
#  'apo': 351,
#  'e': 352,
#  '유전자': 353,
#  '어려움': 354,
#  '조사': 355,
#  '의학': 356,
#  '증도': 357,
#  '전문의': 358,
#  '길': 359,
#  '집': 360,
#  '못': 361,
#  '려면': 362,
#  '찾아가': 363,
#  '야': 364,
#  '기능': 365,
#  '이름': 366,
#  '연락처': 367,
#  '곳': 368,
#  '검색어': 369,
#  '어서': 370,
#  '문진': 371,
#  'ct': 372,
#  '줄': 373,
#  '상담': 374,
#  '원리': 375,
#  '의심': 376,
#  '아버지': 377,
#  '버리': 378,
#  '적절': 379,
#  '찍': 380,
#  '가능': 381,
#  '한지': 382,
#  '평가': 383,
#  '영상': 384,
#  '목적': 385,
#  '통해': 386,
#  '보건소': 387,
#  '소개': 388,
#  '사진': 389,
#  '필수': 390,
#  '진료': 391,
#  '전문': 392,
#  '분야': 393,
#  '어느': 394,
#  '무료': 395,
#  '내원': 396,
#  '아니면': 397,
#  '자기': 398,
#  '공명': 399,
#  '순서': 400,
#  '이루어지': 401,
#  '따라야': 402,
#  '비용': 403,
#  '정도': 404,
#  '기록': 405,
#  '활용': 406,
#  '걸릴까요': 407,
#  '나타났': 408,
#  '조건': 409,
#  '수집': 410,
#  '으면': 411,
#  '보': 412,
#  '메커니즘': 413,
#  '약물': 414,
#  '치료법': 415,
#  '개인': 416,
#  '노력': 417,
#  '근본': 418,
#  '아직': 419,
#  '까지': 420,
#  '없': 421,
#  '목표': 422,
#  '며': 423,
#  '보편': 424,
#  '수술': 425,
#  '시술': 426,
#  '완치': 427,
#  '현재': 428,
#  '줄이': 429,
#  '가족': 430,
#  '소식': 431,
#  '습관': 432,
#  '간헐': 433,
#  '단식': 434,
#  '다양': 435,
#  '후': 436,
#  '예상': 437,
#  '부작용': 438,
#  '보조제': 439,
#  '어떤지': 440,
#  '대안': 441,
#  '서비스': 442,
#  '기대': 443,
#  '개발': 444,
#  '개선': 445,
#  '협력': 446,
#  '다고': 447,
#  '언제': 448,
#  '쯤': 449,
#  '지원': 450,
#  '자연': 451,
#  '요법': 452,
#  '보조': 453,
#  '통제': 454,
#  '전략': 455,
#  '기술': 456,
#  '분': 457,
#  '기간': 458,
#  '접근': 459,
#  '시도': 460,
#  '실천': 461,
#  '재활': 462,
#  '완전히': 463,
#  '다는데': 464,
#  '그런가요': 465,
#  '완화': 466,
#  '시키': 467,
#  '성공률': 468,
#  '식단': 469,
#  '조절': 470,
#  '많': 471,
#  '식이': 472,
#  '추천': 473,
#  '법': 474,
#  '앓': 475,
#  '알코올': 476,
#  '검진': 477,
#  '해석': 478,
#  '센터': 479,
#  '검색': 480,
#  '장소': 481,
#  '잠': 482,
#  '자': 483,
#  '알콜': 484,
#  '테스트': 485,
#  '검': 486,
#  '진': 487,
#  '학과': 488,
#  '소견': 489,
#  '가진': 490,
#  '간단': 491,
#  '서': 492,
#  '유형': 493,
#  '할지': 494,
#  '조언': 495,
#  '술': 496,
#  '예약': 497,
#  '의원': 498,
#  '수면': 499,
#  '심해': 500,
#  '이용': 501,
#  '클리닉': 502,
#  '위치': 503,
#  '조기': 504,
#  '집중력': 505,
#  '떨어지': 506,
#  '유명': 507,
#  '얻': 508,
#  '음주': 509,
#  '잦': 510,
#  '치': 511,
#  '거치': 512,
#  '소요': 513,
#  '전문과': 514,
#  '정확도': 515,
#  '보여': 516,
#  '계신가요': 517,
#  '과다': 518,
#  '요': 519,
#  '발병률': 520,
#  '높일': 521,
#  '꼭': 522,
#  '문의': 523,
#  '적합': 524,
#  '입력': 525,
#  '믿': 526,
#  '없이': 527,
#  '프로그램': 528,
#  '실시': 529,
#  '참고': 530,
#  '오랜': 531,
#  '동안': 532,
#  '특별히': 533,
#  '행동': 534,
#  '과음': 535,
#  '금주': 536,
#  '위험': 537,
#  '최소': 538,
#  '화': 539,
#  '운동': 540,
#  '건강': 541,
#  '식습관': 542,
#  '식품': 543,
#  '영양소': 544,
#  '끊': 545,
#  '가치': 546,
#  '영양가': 547,
#  '음식': 548,
#  '유지': 549,
#  '자제': 550,
#  '취할': 551,
#  '은데': 552,
#  '복용': 553,
#  '마실': 554,
#  '이점': 555,
#  '가져야': 556,
#  '양': 557,
#  '빈도': 558,
#  '접종': 559,
#  '줄일': 560,
#  '음': 561,
#  '주량': 562,
#  '장점': 563,
#  '식사': 564,
#  '전': 565,
#  '적용': 566,
#  '먹': 567,
#  '권고': 568,
#  '환경': 569,
#  '스트레스': 570,
#  '방지': 571,
#  '지켜야': 572,
#  '규칙': 573,
#  '써야': 574,
#  '피하': 575,
#  '금단': 576,
#  '맥주': 577,
#  '예방책': 578,
#  '가질': 579,
#  '도록': 580,
#  '영양제': 581,
#  '마셨': 582,
#  '필름': 583,
#  '끊기': 584,
#  '섭': 585,
#  '취량': 586,
#  '조금': 587,
#  '횟수': 588,
#  '차지': 589,
#  '비율': 590,
#  '높': 591,
#  '은가요': 592,
#  '중독': 593,
#  '을수록': 594,
#  '는지요': 595,
#  '소비': 596,
#  '간': 597,
#  '기여': 598,
#  '이론': 599,
#  '할아버지': 600,
#  '따라': 601,
#  '달라지': 602,
#  '사실': 603,
#  '으로서': 604,
#  '다는': 605,
#  '걸린': 606,
#  '인과': 607,
#  '늦': 608,
#  '악화': 609,
#  '상관': 610,
#  '부분': 611,
#  '주가': 612,
#  '혈관': 613,
#  '상태': 614,
#  '가리키': 615,
#  '의존': 616,
#  '상황': 617,
#  '구체': 618,
#  '그렇': 619,
#  '소비량': 620,
#  '증이': 621,
#  '그것': 622,
#  '두드러지': 623,
#  '관해서': 624,
#  '처음': 625,
#  '경미': 626,
#  '수준': 627,
#  '다가': 628,
#  '점차': 629,
#  '깜박거리': 630,
#  '겪': 631,
#  '블랙아웃': 632,
#  '깜빡': 633,
#  '전날': 634,
#  '흐릿': 635,
#  '평소': 636,
#  '즉시': 637,
#  '중간': 638,
#  '까먹': 639,
#  '지속': 640,
#  '마셔서': 641,
#  '평상시': 642,
#  '표현': 643,
#  '흐려': 644,
#  '정신': 645,
#  '계속': 646,
#  '일': 647,
#  '해당': 648,
#  '깜박': 649,
#  '깜빡하': 650,
#  '지남': 651,
#  '깜빡거리': 652,
#  '대처': 653,
#  '장기간': 654,
#  '가요': 655,
#  '종종': 656,
#  '흐려질': 657,
#  '깜빡깜빡': 658,
#  '볼까요': 659,
#  '흔하': 660,
#  '시킬': 661,
#  '점점': 662,
#  '해질': 663,
#  '경감': 664,
#  '다시': 665,
#  '거쳐서': 666,
#  '고려': 667,
#  '기기': 668,
#  '도구': 669,
#  '준비': 670,
#  '재': 671,
#  '관찰': 672,
#  '마신': 673,
#  '남성': 674,
#  '으셨다면': 675,
#  '질문': 676,
#  '스스로': 677,
#  '안': 678,
#  '뚜렷': 679,
#  '따르': 680,
#  '자료': 681,
#  '격리': 682,
#  '치유': 683,
#  '바꾸': 684,
#  '해결': 685,
#  '보호': 686,
#  '장비': 687,
#  '선택': 688,
#  '다루': 689,
#  '반드시': 690,
#  '높이': 691,
#  '과도': 692,
#  '회복': 693,
#  '취하': 694,
#  '반응': 695,
#  '옵션': 696,
#  '성공': 697,
#  '률': 698,
#  '약': 699,
#  '제한': 700,
#  '대체': 701,
#  '조성': 702,
#  '바꿔야': 703,
#  '합병증': 704,
#  '우울': 705,
#  '감정': 706,
#  '우울증': 707,
#  '걱정': 708,
#  '없앨': 709,
#  '산후': 710,
#  '처방': 711,
#  '세로토닌': 712,
#  '재흡수': 713,
#  '억제제': 714,
#  '빨리': 715,
#  '호전': 716,
#  '해도': 717,
#  '오래': 718,
#  '푸': 719,
#  '록': 720,
#  '틴': 721,
#  '불구': 722,
#  '이러': 723,
#  '두': 724,
#  '동시': 725,
#  '작': 726,
#  '질수록': 727,
#  '빠른': 728,
#  '피해야': 729,
#  '통한': 730,
#  '가져다주': 731,
#  '거부': 732,
#  '복용량': 733,
#  '멍해': 734,
#  '꾸준히': 735,
#  '어도': 736,
#  '기분': 737,
#  '아침': 738,
#  'adhd': 739,
#  '모유': 740,
#  '수유': 741,
#  '몸': 742,
#  '는다면': 743,
#  '임의': 744,
#  '중단': 745,
#  '은지': 746,
#  '안전': 747,
#  '아기': 748,
#  '부정': 749,
#  '공황': 750,
#  '성분': 751,
#  '두통약': 752,
#  '증가': 753,
#  '꾸준': 754,
#  '사라질': 755,
#  '일시': 756,
#  '멈출': 757,
#  '제': 758,
#  '마음대로': 759,
#  '자신': 760,
#  '감': 761,
#  '능력': 762,
#  '향상': 763,
#  '고통': 764,
#  '경구': 765,
#  '용': 766,
#  '말기': 767,
#  '신': 768,
#  '질물': 769,
#  '더라도': 770,
#  '생길': 771,
#  '뇌전증': 772,
#  '미칠까요': 773,
#  '오랫동안': 774,
#  '했': 775,
#  '해소': 776,
#  '항우울제': 777,
#  '알프라졸람': 778,
#  '나빠': 779,
#  '입증': 780,
#  '출산': 781,
#  '혜택': 782,
#  '극복': 783,
#  '장기': 784,
#  '호흡': 785,
#  '증후군': 786,
#  '중지': 787,
#  '괜찮': 788,
#  '걸까요': 789,
#  '막': 790,
#  '옳': 791,
#  '겠': 792,
#  '쓰이': 793,
#  '약효': 794,
#  '야기': 795,
#  '없애': 796,
#  '편': 797,
#  '더뎌': 798,
#  '심해질': 799,
#  '치료제': 800,
#  '진다면': 801,
#  '사라지': 802,
#  '질': 803,
#  '사회': 804,
#  '어려운': 805,
#  '특화': 806,
#  '가져올까요': 807,
#  '조합': 808,
#  '빠르': 809,
#  '증약': 810,
#  '상호': 811,
#  '어려울': 812,
#  '까요': 813,
#  '후유증': 814,
#  '남': 815,
#  '비해': 816,
#  '가져올': 817,
#  '감소': 818,
#  '같이': 819,
#  '일으킬': 820,
#  '미미': 821,
#  '강화': 822,
#  '으면서': 823,
#  '통': 824,
#  '아도': 825,
#  '정서': 826,
#  '발달': 827,
#  '긴': 828,
#  '또는': 829,
#  '사례': 830,
#  '부담': 831,
#  '우려': 832,
#  '시기': 833,
#  '정상': 834,
#  '완쾌': 835,
#  '체중': 836,
#  '줄어들': 837,
#  '제대로': 838,
#  '및': 839,
#  '재발': 840,
#  '된다면': 841,
#  '초래': 842,
#  '영양': 843,
#  '낮': 844,
#  '그러나': 845,
#  '계시': 846,
#  '아닌가요': 847,
#  '유일': 848,
#  '해결책': 849,
#  '갱년기': 850,
#  '자외선': 851,
#  '노출': 852,
#  '피부암': 853,
#  '등': 854,
#  '골다공증': 855,
#  '햇볕': 856,
#  '쬐': 857,
#  '자살': 858,
#  '정신과': 859,
#  '조현': 860,
#  '이어지': 861,
#  '요즘': 862,
#  '외롭': 863,
#  '느낀다면': 864,
#  '외로움': 865,
#  '영향력': 866,
#  '큰지': 867,
#  '만사': 868,
#  '욕': 869,
#  '된다는': 870,
#  '심리': 871,
#  '진다는데': 872,
#  '처럼': 873,
#  '활기차': 874,
#  '힘들': 875,
#  '느껴': 876,
#  '외부': 877,
#  '이후': 878,
#  '연결': 879,
#  '고리': 880,
#  '주된': 881,
#  '이어질': 882,
#  '여야': 883,
#  '현황': 884,
#  '이런': 885,
#  '느껴진다면': 886,
#  '아이': 887,
#  '낳': 888,
#  '내부': 889,
#  '소': 890,
#  '오메가': 891,
#  '3': 892,
#  '지방산': 893,
#  '여성': 894,
#  '폐경': 895,
#  '긍정': 896,
#  '학교': 897,
#  '싫': 898,
#  '음증': 899,
#  '삶': 900,
#  '멍한': 901,
#  '증과': 902,
#  '폐경기': 903,
#  '소아': 904,
#  '과잉': 905,
#  '기복': 906,
#  '충동': 907,
#  '불안': 908,
#  '웃': 909,
#  '으려고': 910,
#  '얼굴': 911,
#  '일부': 912,
#  '산모': 913,
#  '산욕기': 914,
#  '불안감': 915,
#  '불': 916,
#  '죄책감': 917,
#  '느낌': 918,
#  '바닥': 919,
#  '내려가': 920,
#  '호로': 921,
#  '몬': 922,
#  '무기력감': 923,
#  '징후': 924,
#  '상실감': 925,
#  '무력감': 926,
#  '분류': 927,
#  '표정': 928,
#  '변동': 929,
#  '일어날': 930,
#  '드': 931,
#  '성향': 932,
#  '무': 933,
#  '기력': 934,
#  '눈물': 935,
#  '전형': 936,
#  '이것': 937,
#  '안정': 938,
#  '생겨': 939,
#  '살': 940,
#  '갑자기': 941,
#  '피로감': 942,
#  '헌팅': 943,
#  '톤': 944,
#  '병과': 945,
#  '분만': 946,
#  '일치': 947,
#  '딸': 948,
#  '울음': 949,
#  '소리': 950,
#  '짜증': 951,
#  '시달리': 952,
#  '성욕': 953,
#  '복부비만': 954,
#  '함': 955,
#  '6': 956,
#  '개월': 957,
#  '창문': 958,
#  '울': 959,
#  '식은땀': 960,
#  '열감': 961,
#  '을지': 962,
#  '다를까요': 963,
#  '가을': 964,
#  '무기력증': 965,
#  '심하': 966,
#  '나타난': 967,
#  '임신': 968,
#  '차': 969,
#  '식욕': 970,
#  '으며': 971,
#  '오': 972,
#  '하루': 973,
#  '몇': 974,
#  '번': 975,
#  '마음': 976,
#  '허탈감': 977,
#  '월경': 978,
#  '세상': 979,
#  '사': 980,
#  '재미': 981,
#  '긴장': 982,
#  '초조': 983,
#  '늘': 984,
#  '피곤': 985,
#  '졸리': 986,
#  '느껴질': 987,
#  '갑작스러운': 988,
#  '슬픔': 989,
#  '뒤': 990,
#  '자꾸': 991,
#  '혹시': 992,
#  '아닌지': 993,
#  '지난': 994,
#  '슬픈': 995,
#  '허탈': 996,
#  '무기력': 997,
#  '지연': 998,
#  '갑작': 999,
#  ...}

# %%
all_word
# Out:
# {'합니다.ssri에는',
#  '시작합니다.치매의',
#  '스스로는',
#  '요소입니다.치매',
#  '실시합니다.일반적으로',
#  '불안제가',
#  '싶은데',
#  '여기는',
#  '있습니다.주로',
#  '빈도의',
#  '수집',
#  '중요합니다.지속적인',
#  '도구입니다.최근',
#  '닫는',
#  '여기지',
#  '생활습관은',
#  '제공합니다.근력',
#  '활동적이고,',
#  '40대에서',
#  '차단제,',
#  '합니다.환자가',
#  '잊어버렸을',
#  '것입니다.이러한',
#  '환경이',
#  '찾지는',
#  '입힐',
#  '환자들은',
#  '사이에',
#  '연구되고',
#  '다하고,',
#  '됩니다.우울증에',
#  '장기간에',
#  '중요합니다.건강',
#  '합니다.알츠하이머병의',
#  '제공합니다.다양한',
#  '무기력하게',
#  '활성화에',
#  '있습니다.식사를',
#  '세포와',
#  '올란자핀과',
#  '지켜보아야',
#  '안주와',
#  '풀어주고',
#  '팔,',
#  '실조,',
#  '약물치료도',
#  '경도의',
#  '좋습니다.놀이와',
#  '얇아지는',
#  '피곤하거나',
#  '주제가',
#  '치료제로는',
#  '부분의',
#  '심각할',
#  '약물들도',
#  '의존과',
#  '질병인지,',
#  '현재로서',
#  '의지대로',
#  '혈액순환,',
#  '정신치료에서는',
#  '자가진단하는데',
#  '유발하는데,',
#  '아밀로이드는',
#  '뇌혈관을',
#  '추천하시나요?',
#  '헌팅톤',
#  '소요되고',
#  '수행이나',
#  '시각화하여',
#  '비롯되는',
#  '사라지더라도',
#  '집중력이나',
#  '혹은',
#  '노화시키고',
#  '보행을',
#  '혼동하거나',
#  '방법입니다.주로',
#  '제공합니다.알코올성',
#  '체크할',
#  '문법적으로',
#  '곡류',
#  '옳은가요?',
#  '글이',
#  '신경질환이며,',
#  '좋습니다.술을',
#  '중요합니다.연구',
#  '있습니다.일상적인',
#  '삼습니다.알츠하이머병이나',
#  '그리기',
#  '불안감입니다.',
#  '감독하에',
#  '이들은',
#  '심리평가에서는',
#  '정책과',
#  '시각인지',
#  '심각하지',
#  '알려드리겠습니다.',
#  '의존자들은',
#  '부신기능부전,',
#  '징후들이',
#  '병행이',
#  '합니다.종합적으로,',
#  '만성질환',
#  '환자들과',
#  '20의',
#  '중요성을',
#  '진행되기도',
#  '손상됩니다.치매는',
#  '일종으로,',
#  '대신,',
#  '조언',
#  '칼로리',
#  '돌이킬',
#  '심리상담사의',
#  '한다.정확한',
#  '전망을',
#  '흐름이',
#  '병태생리의',
#  '기반으로',
#  '초래합니다.현재까지는',
#  '주거나,',
#  '질문을',
#  '특이적인',
#  '전달물질을',
#  '합니다.정확한',
#  '된다.',
#  '생활환경,',
#  '사용합니다.항정신병',
#  '처방할',
#  '대처는',
#  '도울',
#  '쉽고',
#  '올란자핀과는',
#  '이루고',
#  '지각능력',
#  '권장사항을',
#  '찾습니다.치매',
#  '촬영도',
#  '알아듣지',
#  '접근으로',
#  '뇌혈관',
#  '종류이지만,',
#  '미네랄은',
#  '부족하지',
#  '줄였을',
#  '중요합니다.보드게임이나',
#  '주시하고,',
#  '작동하지',
#  '자가진단만으로',
#  '지나지',
#  '변화하게',
#  '계통',
#  '조절하거나',
#  '아홉째,',
#  'b2,',
#  '20를',
#  '체계의',
#  '힘을',
#  '관여되나요?',
#  '실천적인',
#  '방식과',
#  '좋고',
#  '사건에',
#  '제공됩니다.알코올성',
#  '있기를',
#  '발생하여,',
#  '자극시키고',
#  '있습니다.치료',
#  '50로',
#  '침울함과',
#  '향상된',
#  '남성이',
#  '그러나',
#  '나타나면서',
#  '아포지단백질과',
#  '특징으로',
#  '진행속도가',
#  '없습니다.치매',
#  '운동량을',
#  '예방하지',
#  '심호흡과',
#  '고려되어',
#  '관련되며,',
#  '85의',
#  '있습니다.그러므로',
#  '셀레질린,',
#  '절차들을',
#  '통신을',
#  '분류됩니다.일반적으로,',
#  '7585에',
#  '우울증이라고',
#  '아밀로이드에',
#  '질문',
#  '일으킵니다.하지만,',
#  '정신운동',
#  '기록합니다.',
#  '방법은',
#  '소화불량,',
#  '신경계통에',
#  '있습니다.생물학적인',
#  '지인들이',
#  '의료기기나',
#  '됩니다.술을',
#  '공급받는',
#  '진료부터',
#  '주며,',
#  '생선,',
#  '향상에도',
#  '일상활동들에는',
#  '말합니다.정신',
#  '막혀서',
#  '저하는',
#  '프로그램,',
#  '체크와',
#  '망상과',
#  '비흡연자도',
#  '높으며,',
#  '해결책은',
#  '사용됩니다.ssriselective',
#  '특별한',
#  '받으세요.치매',
#  '보이면,',
#  '베타아밀로이드가',
#  '이르면',
#  '참여하나요?',
#  '손실',
#  '재발이나',
#  '정신건강의학적인',
#  '감미료와',
#  '생성의',
#  '항불안제는',
#  '일상에서',
#  '섬유매듭을',
#  '국물이나',
#  '다양합니다.먼저,',
#  '효과적입니다.그러나',
#  '방법이지만',
#  '어려움이나',
#  '모두에게',
#  '물질도',
#  '왜곡,',
#  '주변에',
#  '것입니다.하지만',
#  '평소와',
#  '스폰지와',
#  '공간을',
#  '적절하게',
#  '흔한데,',
#  '소염제,',
#  '만들어냅니다.',
#  '질환과도',
#  '정의',
#  '성인',
#  '타인을',
#  '조절하거나,',
#  '찍어보는',
#  '투약하는',
#  '합니다.기억력의',
#  '동작은',
#  '보고된',
#  '수립됩니다.알츠하이머병은',
#  '조심을',
#  '협착이나',
#  '작용제',
#  '병변은',
#  '부족하게',
#  '아직도',
#  '과음과',
#  '중요합니다.운동을',
#  '벗어나기',
#  'ganzheitlicheschromdenten,',
#  '심인성',
#  '비흡연이',
#  '특정한',
#  '운동과',
#  '약물요법과',
#  '의미할까요?',
#  '보장하는',
#  '더욱이,',
#  '쾌적한',
#  '지시를',
#  '즐거움도',
#  '46주',
#  '훈련시키거나',
#  '있습니다.정신건강',
#  '방문하면서',
#  '중요합니다.예를',
#  '됩니다.술과',
#  '포함됩니다.',
#  '지원체계를',
#  '부분인',
#  '장애이므로,',
#  '할머니의',
#  '능력을',
#  '존재하지만,',
#  '익히고,',
#  '있습니다.실제로,',
#  '집중하여',
#  '만들어가는',
#  '두뇌를',
#  '활성제',
#  '일상',
#  '그들과',
#  '신경독성',
#  '치료하지는',
#  '힘들어질',
#  '수준이었다가',
#  '탐구하고',
#  '있습니다.최근에는',
#  '개인',
#  '에어로빅,',
#  '있었지만,',
#  '하는',
#  '운동에는',
#  '수면의',
#  '저하시킵니다.알츠하이머병은',
#  '유사하나',
#  '처리하는',
#  '일반적입니다.알츠하이머병의',
#  '시공간파악능력,',
#  '방법알코올성',
#  '발생합니다.알코올',
#  '문제뿐만',
#  'b1이',
#  '소외감을',
#  '악화나',
#  '야기합니다.알츠하이머병은',
#  '적으며,',
#  '수면장애는',
#  '완화가',
#  '질환이다.우울증은',
#  '의미합니다.따라서,',
#  '관념이',
#  '1020대에서',
#  '기능과',
#  '폭력성과',
#  '건강의학과에서',
#  '소통,',
#  '불능해지며,',
#  '실시하면',
#  '게임도',
#  '염려와',
#  '선별적인',
#  '장치와',
#  '나타났던',
#  '목적으로',
#  '진단되나요?알코올성',
#  '있습니다.유전적',
#  '질환입니다.따라서,',
#  '소비입니다.알코올성',
#  '아리피프라졸,',
#  '청소년에게는',
#  '지각장애',
#  '파괴할',
#  '줄어듭니다.담배를',
#  '통합을',
#  '전환하도록',
#  '경험한',
#  '금단',
#  '심해서',
#  '저하시킬',
#  '야채,',
#  '기울이게',
#  '지방산에',
#  '요인으로',
#  '핵의학검사는',
#  '섭취하며',
#  '바에',
#  '변동과',
#  '요소입니다.알츠하이머병의',
#  '80100분',
#  '기분장애도',
#  '알도스테론제를',
#  '대안을',
#  '진단을',
#  '없어지게',
#  '억제하고',
#  'oga는',
#  '과도',
#  '의존합니다.',
#  '이름으로',
#  '셀르트랄린은',
#  '손실되며,',
#  '3점까지',
#  '늦어져',
#  '훈련이나',
#  '돕기',
#  '요법과',
#  '다릅니다.알츠하이머병의',
#  '알아보겠습니다.',
#  '효과적이고',
#  '식습관,',
#  '편이며,',
#  '베타는',
#  '협조를',
#  '사람이',
#  '감퇴,',
#  '사용합니다.약물치료의',
#  '다양하게',
#  '돕습니다.인지행동치료는',
#  '느려지며,',
#  '혼동되는',
#  '권고에',
#  '다운증후군을',
#  '활동을',
#  '요법과의',
#  '우리나라도',
#  '방법입니다.우울증에',
#  '않으므로',
#  '좋아지게',
#  '정신에',
#  '국가에서는',
#  '강화로',
#  '도와줍니다.요약하면,',
#  '필요합니다.치매',
#  '맞을까요?',
#  '의존성',
#  '촉진하는데',
#  '능력,',
#  '계산능력과',
#  '활동과',
#  '감소와',
#  '가능하면',
#  '소포와',
#  '혼동될',
#  '시간감각',
#  '컴퓨터단층촬영,',
#  '얇아져',
#  '전기경련요법은',
#  '됩니다.매일',
#  '시각으로',
#  '포함합니다.첫째로,',
#  '조절,',
#  '관리하세요.치매',
#  '걸쳐',
#  '희석되므로',
#  '않고도',
#  '있습니다.검사',
#  '국가와',
#  '보여줄',
#  '잃은',
#  '트라우마를',
#  '구조적인',
#  '절반',
#  '사회로의',
#  '약물입니다.우울증',
#  '예방도',
#  '포함하며,',
#  '있습니다.현재로서는',
#  '8잔',
#  '보충을',
#  '광선',
#  '적응증이나',
#  '강도의',
#  '요가',
#  '옵션을',
#  '사회의',
#  '예방입니다.ssris선택적',
#  'norepinephrine의',
#  '유전학적으로는',
#  '척도,',
#  '빨라서',
#  '맞출',
#  '개선입니다.약물',
#  '3040대의',
#  '물질의',
#  '일반적입니다.폴스타인',
#  '기술이',
#  '분류합니다.이를',
#  '이상이더라도',
#  '걸리지',
#  '받아',
#  '증진시키는데',
#  '고통은',
#  '테스트해보고',
#  '방문하면,',
#  '장단점을',
#  '얼굴의',
#  '영역에',
#  '시도해보세요.',
#  '시행합니다.이러한',
#  '확인되었습니다.유전적인',
#  '지지정신치료와',
#  '우울증세,',
#  '프리버지',
#  '가짐으로써',
#  '찾아내고,',
#  '아기의',
#  '흐려집니다.알츠하이머병은',
#  '아발론,',
#  '평가하고자',
#  '중요합니다.알코올은',
#  '컴퓨터',
#  '보여주는',
#  '중독과는',
#  '신체질환과',
#  '신경을',
#  '추구할',
#  '회복과',
#  '검진을',
#  '변화로,',
#  '있습니다.매일',
#  '그러므로,',
#  '탄수화물,',
#  '늘려가면',
#  '가능합니다.',
#  '뇌병증이라는',
#  '비스포스포네이트,',
#  '변연계의',
#  '분류되고',
#  '매뉴얼dsm5에',
#  '빠르고',
#  '안정,',
#  '피곤하고',
#  '단일광자방출컴퓨터단층촬영을',
#  '위험하며,',
#  '중요합니다.다양한',
#  '불안장애',
#  '건강상의',
#  '지방세포로의',
#  '점수는',
#  '입으면서',
#  '이루어지나요?',
#  '재생에',
#  '있게',
#  '병행을',
#  '지원하고,',
#  '시작하는데,',
#  '충격적인',
#  '보호자로부터',
#  '좋습니다.둘째,',
#  '정신적',
#  '일반인들도',
#  '알츠하이머라는',
#  '선택의',
#  '동안에도',
#  '의존하거나',
#  '필요로',
#  '평가될',
#  '소비',
#  '흐릿해지고,',
#  '없는지',
#  '치료제입니다.',
#  '콩제품을',
#  '시험이',
#  '실험적인',
#  '깨질',
#  '한다.현재는',
#  '교류하면서',
#  '있습니다.먼저,',
#  'protein이라는',
#  '식단이',
#  '기대할',
#  '대화하고',
#  '침착이',
#  '변화만을',
#  '자아존중감과',
#  '동작,',
#  '사회생활에도',
#  '알려주고',
#  '내용과',
#  '청취한',
#  '작용에',
#  '지속적이며',
#  '필수적인',
#  '없이도',
#  '화학물질을',
#  '복용',
#  '확인되었습니다.알츠하이머병은',
#  '10에서',
#  '시도하고,',
#  '원인에는',
#  'ps1',
#  '문제이며,',
#  '이상에',
#  '잊어버리거나,',
#  '기록의',
#  '제한하세요.',
#  '단기',
#  '주목합니다.',
#  '포함됩니다.주석',
#  '차리는',
#  '진찰',
#  '존재합니다.',
#  '해리',
#  '상태이고,',
#  '누출,',
#  '이루어집니다.진단을',
#  '읽기',
#  '항우울',
#  '파열로',
#  '알려진',
#  '작동시키고',
#  '정신을',
#  '불안정을',
#  '불안함과',
#  '회복시킴으로써',
#  '극복에',
#  '나타납니다.우울증의',
#  '신경전달물질이',
#  '테스트해봅니다.',
#  'test는',
#  '섭취하지',
#  '적신',
#  '미치게',
#  '다양한',
#  '운동신경세포의',
#  '조성,',
#  '체크하고',
#  '손상입니다.알츠하이머병의',
#  'a',
#  '손떨림',
#  '느끼면서',
#  '결합물질의',
#  '중요합니다.뇌로',
#  '보완하기',
#  '현상,',
#  '이루어집니다.따라서',
#  '유지입니다.',
#  '자전거와',
#  '뇌신경세포를',
#  '발견과',
#  '어렵다.',
#  '위치에',
#  '달리,',
#  '연령,',
#  '일에',
#  '입증되었습니다.알맞은',
#  '의료검진,',
#  '조절을',
#  '도와줍니다.3.',
#  '정신행동장애도',
#  '활동입니다.보드게임과',
#  '않습니다.우울증',
#  '남녀',
#  '인터뷰와',
#  '없어지고',
#  '피워서는',
#  '일들에서',
#  '종류로,',
#  '모임,',
#  'antidepressants가',
#  '정신적으로도',
#  '입어',
#  '중단해도',
#  '진단검사를',
#  '현재까지,',
#  '파괴되는',
#  '폭음을',
#  '불안감을',
#  '폐기능을',
#  '양치를',
#  '소멸이',
#  '기억장애가',
#  '철저한',
#  '30세',
#  '방법',
#  '인지하고,',
#  '생명의',
#  '움직이기가',
#  '예방접종이',
#  '60대',
#  '평가입니다.정신건강',
#  '섭취량',
#  '잃게',
#  '프리버스트',
#  '개선시켜줍니다.',
#  '교정하며',
#  '의료기관',
#  '좋습니다.운동과',
#  '되므로',
#  '니코틴이',
#  '형태입니다.알츠하이머병의',
#  '행동인지',
#  '내성',
#  '하나입니다.현재까지는',
#  '돌아오면',
#  '간성',
#  '확대하는',
#  '야외로',
#  '요인이나',
#  '지식을',
#  '결정해야',
#  '내',
#  '억제하여',
#  '테스트dsm5로,',
#  '없애기',
#  '다양하여',
#  '중요합니다.phq9',
#  '도구입니다.최근의',
#  '파키슨',
#  '6090로',
#  '이별이나',
#  '노화와는',
#  '호흡운동도',
#  '조사해',
#  'disorders의',
#  '조합에',
#  '오해와',
#  '적어집니다.',
#  '평가는',
#  '갱년기나',
#  '재발과',
#  '발생한다.치매는',
#  '확인했습니다.아세틸콜린',
#  '보완적으로',
#  '서로에게',
#  '의심하고',
#  '초래하고',
#  '핵의학검사나',
#  '감수성,',
#  '떨어지며,',
#  '자해',
#  '지도하에',
#  '프로프라놀롤,',
#  '절제를',
#  '감소합니다.치매의',
#  '것들이다.',
#  '저항성',
#  '필요합니다.건강한',
#  '불규칙하고,',
#  '기억된',
#  '적게하고,',
#  '쬐는',
#  '사건들이',
#  '언제인가요?',
#  '요인인가요?',
#  '있습니다.혈관',
#  '진행되면',
#  '구별되는',
#  '사용합니다.항우울제는',
#  '영양소',
#  '증상입니다.우울증',
#  '영양섭취를',
#  '체온을',
#  '의존자는',
#  '자식',
#  '기분장애와는',
#  '불규칙하게',
#  '뇌신경질환인',
#  '무기력이',
#  '기억상실,',
#  '합니다.일주일에',
#  '실조증과',
#  '병에',
#  '어려워지거나',
#  '나누어지는데,',
#  '목어깨',
#  '제공합니다.mri',
#  '분석학',
#  '구강,',
#  '사용됩니다.ssri',
#  '설문지와',
#  '벤조디아제핀과',
#  '신경전달물질로,',
#  '언어능력이',
#  '콜린성',
#  '약물치료에는',
#  '차이에',
#  '알아보겠습니다.우울증의',
#  '포함합니다.따라서,',
#  '2040대에서도',
#  '콜린에스테라제를',
#  '정신건강은',
#  '완치될',
#  '경치',
#  '줍니다.위와',
#  '발전은',
#  '도네페질,',
#  '셋째로,',
#  '제한하고,',
#  '높아집니다.비타민',
#  '건망증으로,',
#  '나이가',
#  '진단됩니다.우울증',
#  '만성적이고',
#  '머리를',
#  '의료기관에서',
#  '60대에서',
#  '발생합니다.치매는',
#  '중년층,',
#  '아포지단백',
#  '키워줍니다.',
#  '흥미가',
#  '향상되고',
#  '평가만으로도',
#  '최소화합니다.',
#  '진입으로',
#  '빈도',
#  '치매보다는',
#  '변하고',
#  '증상을',
#  '있습니다.우울증의',
#  '걱정을',
#  '유지시키고',
#  '종양',
#  '폐렴과',
#  '지각하는',
#  '받으시기',
#  '과거력,',
#  '나타나지만',
#  '문제해결능력,',
#  '생각되었으나,',
#  '문의하는',
#  '이것은',
#  '활동들은',
#  '존재하는',
#  '상실증과',
#  '관리에',
#  '제어하고,',
#  '심리검사의',
#  '평가',
#  '다양합니다.환자들이',
#  '찾아보세요.',
#  '사용되거나',
#  '정보의',
#  '전략은',
#  '약해진',
#  '기분안정제,',
#  '뇌내의',
#  '나이에서',
#  '자가진단과',
#  '병변',
#  '기법이',
#  '일어났던',
#  '동반하기',
#  '나타나므로',
#  '이상이라면,',
#  'cdr',
#  '지연되며,',
#  '이외에도,',
#  '심리학자,',
#  '설명을',
#  '유전질환',
#  '힘들기',
#  '뒤에는',
#  '10가',
#  '차지합니다.치매는',
#  '권장하시는지',
#  '장기기억이',
#  '실시됩니다.따라서,',
#  '기대됩니다.알츠하이머병',
#  '수행됩니다.1.',
#  '해치고',
#  '어린',
#  '조합되어야',
#  '제한,',
#  '하나입니다.',
#  '예정입니다.',
#  '절망감을',
#  '나타나기',
#  '효과적입니다.주로',
#  '노인성',
#  '단계입니다.',
#  '병의',
#  '기본적으로',
#  '처방될',
#  '있습니다.생체학적인',
#  '하나입니다.주요',
#  '채',
#  '나이들어감에',
#  '피우기를',
#  '의지가',
#  '스타일,',
#  '메틸페니데이트는',
#  '청취하고,',
#  '40세',
#  '정밀',
#  '콜린성약,',
#  '수와',
#  'lexa와',
#  '1020를',
#  '해결하거나',
#  '항우울제보다',
#  '작용하여',
#  '있었다는',
#  '인자가',
#  '확실히',
#  '지속됩니다.일반적으로',
#  '알아야',
#  '못하며',
#  '사람들과',
#  '명명한',
#  '형태이므로',
#  '활성화하여',
#  '개선될',
#  'ssris,',
#  '작동제는',
#  '심혈관질환과',
#  '있습니다.이외에도',
#  '투여는',
#  '적거나,',
#  '병원이',
#  '인지행동요법은',
#  '고지방고당분',
#  '됩니다.이렇게',
#  '구축하고,',
#  '문이',
#  '이름과',
#  '아빠의',
#  '나타났습니다.따라서',
#  '한병씩',
#  '형성되었던',
#  '활성화하고,',
#  '차지합니다.알츠하이머병은',
#  '필요합니다.뇌',
#  '표현이거나',
#  '플라크를',
#  '항정신병제나',
#  '되었습니다.알츠하이머병의',
#  '적게',
#  '기법들은',
#  '미칩니다.알코올',
#  '명백하지',
#  '감소하고,',
#  '저하된다는',
#  '오래전',
#  '도움은',
#  '우울증에서',
#  '치료제에',
#  '대답하지',
#  '메칠페니데이트,',
#  '맥박을',
#  '초기,',
#  '유도하여',
#  'nazethin이',
#  '아드레날린과',
#  '떨어져',
#  '시행됩니다.정확한',
#  '잊음이',
#  '잃어',
#  '언어표현',
#  '있습니다.간단한',
#  '입증하였습니다.',
#  '결핍에',
#  '건강,',
#  '할까요?치매는',
#  '부자유',
#  '정상적으로',
#  '증가시켜줍니다.약물',
#  '식욕은',
#  '파악하는',
#  '하기',
#  '비흡연자와',
#  '환기시키는',
#  '무가치감,',
#  '기억을',
#  '정신역동적',
#  '근력을',
#  '신경물질',
#  '밝기',
#  '메커니즘은',
#  '나타납니다.따라서,',
#  '두께가',
#  '있습니다.예방',
#  '보존하는',
#  '기름과',
#  '시행되며,',
#  '자극과',
#  '방법들은',
#  '겪습니다.우울증은',
#  '완화시킵니다.이',
#  '분해되어',
#  '작용하는지',
#  '처방하여',
#  '행동하는',
#  '병원이나',
#  '질병이며',
#  '지속에',
#  '균형이',
#  '높아졌습니다.',
#  '신경물질과',
#  '도와줍니다.mri',
#  '후로',
#  '중독된',
#  '요인들에는',
#  '악화되지',
#  '독성',
#  '추천되는',
#  '포름알데히드',
#  '프로작이나',
#  '극복하는데',
#  '반응도',
#  '이르는',
#  '일으킵니다.뇌가',
#  '우리나라는',
#  '모니터링과',
#  '정신사회적',
#  '23시간',
#  'health',
#  '질환이다.알츠하이머병은',
#  '언급을',
#  '규정하기보다는',
#  '증상들에',
#  '알츠하이머병의',
#  '기분부전장애를',
#  '중단을',
#  '해결하는',
#  '안절부절',
#  ...}

# %%
vocab
# Out:
# {'<PAD>': 0,
#  '<SOS>': 1,
#  '<EOS>': 2,
#  '<UNK>': 3,
#  '알츠하이머병': 4,
#  '의': 5,
#  '원인': 6,
#  '으로': 7,
#  '매일': 8,
#  '소주': 9,
#  '를': 10,
#  '섭취': 11,
#  '하': 12,
#  '는': 13,
#  '것': 14,
#  '이': 15,
#  '언급': 16,
#  '되': 17,
#  '고': 18,
#  '있': 19,
#  '는데': 20,
#  ',': 21,
#  '에': 22,
#  '대한': 23,
#  '근거': 24,
#  '가': 25,
#  '는지': 26,
#  '알려': 27,
#  '주': 28,
#  '세요': 29,
#  '.': 30,
#  '라는': 31,
#  '질병': 32,
#  '은': 33,
#  '유전': 34,
#  '적': 35,
#  '영향': 36,
#  '을': 37,
#  '받': 38,
#  '인가요': 39,
#  '?': 40,
#  '발생': 41,
#  '연구': 42,
#  '나': 43,
#  '발견': 44,
#  '진행': 45,
#  '중': 46,
#  '발병': 47,
#  '과': 48,
#  '관련': 49,
#  '여': 50,
#  '뇌': 51,
#  '노화': 52,
#  '로': 53,
#  '인한': 54,
#  '증상': 55,
#  '된': 56,
#  '결과': 57,
#  '을까요': 58,
#  '무엇': 59,
#  '주요': 60,
#  '예방': 61,
#  '위해': 62,
#  '한': 63,
#  '병': 64,
#  '씩': 65,
#  '권장': 66,
#  '이유': 67,
#  '다른': 68,
#  '들': 69,
#  '대해': 70,
#  '데': 71,
#  '미치': 72,
#  '요인': 73,
#  '어떤': 74,
#  '나요': 75,
#  '치매': 76,
#  '사이': 77,
#  '어떠': 78,
#  '연관': 79,
#  '성': 80,
#  '하나': 81,
#  '인': 82,
#  '대해서': 83,
#  '자세히': 84,
#  '가족력': 85,
#  '이외': 86,
#  '상세': 87,
#  '게': 88,
#  '설명': 89,
#  '해': 90,
#  '그': 91,
#  '따른': 92,
#  '알': 93,
#  '싶': 94,
#  '어요': 95,
#  '과정': 96,
#  '에서': 97,
#  '가장': 98,
#  '문제': 99,
#  '될': 100,
#  '수': 101,
#  '감염': 102,
#  '균': 103,
#  '정의': 104,
#  '와': 105,
#  '특징': 106,
#  '30': 107,
#  '대': 108,
#  '더': 109,
#  '쉽': 110,
#  '찾아볼': 111,
#  '외': 112,
#  '생기': 113,
#  '현상': 114,
#  '차이점': 115,
#  '알려져': 116,
#  '일어나': 117,
#  '큰': 118,
#  '역할': 119,
#  '마시': 120,
#  '란': 121,
#  '습니다': 122,
#  '확인': 123,
#  '기': 124,
#  '의료': 125,
#  '기관': 126,
#  '방문': 127,
#  '해야': 128,
#  '자세': 129,
#  '듣': 130,
#  '중요': 131,
#  '사항': 132,
#  '흔히': 133,
#  '위한': 134,
#  '조치': 135,
#  '예방법': 136,
#  '나이': 137,
#  '젊': 138,
#  '사람': 139,
#  '에게': 140,
#  '도': 141,
#  '많이': 142,
#  '나타나': 143,
#  '알려진': 144,
#  '존재': 145,
#  '40': 146,
#  '세': 147,
#  '인데': 148,
#  '의해': 149,
#  '할': 150,
#  '일으키': 151,
#  '최신': 152,
#  '요소': 153,
#  '걸리': 154,
#  '이나': 155,
#  '신체': 156,
#  '변화': 157,
#  '주의': 158,
#  '가설': 159,
#  '실': 160,
#  '실험': 161,
#  '진단': 162,
#  '검사': 163,
#  '검토': 164,
#  '할까요': 165,
#  '내': 166,
#  '머리': 167,
#  '속': 168,
#  '지우개': 169,
#  '영화': 170,
#  '나오': 171,
#  '일까요': 172,
#  '위해서': 173,
#  '필요': 174,
#  '한가요': 175,
#  '거나': 176,
#  '관리': 177,
#  '취해야': 178,
#  '인지': 179,
#  '관계': 180,
#  '걸릴': 181,
#  '정보': 182,
#  '퇴행': 183,
#  '최근': 184,
#  '었': 185,
#  '방법': 186,
#  '사용': 187,
#  '추가': 188,
#  '종류': 189,
#  '인자': 190,
#  '효과': 191,
#  '기억': 192,
#  '장애': 193,
#  '언어': 194,
#  '서로': 195,
#  '다른가요': 196,
#  '한다면': 197,
#  '공통점': 198,
#  '정확': 199,
#  '의료진': 200,
#  '제공': 201,
#  '질환': 202,
#  '어': 203,
#  '주장': 204,
#  '점': 205,
#  '관여': 206,
#  '유사': 207,
#  '면서': 208,
#  '건가요': 209,
#  '노인': 210,
#  '에게서': 211,
#  '주로': 212,
#  '작용': 213,
#  '자주': 214,
#  '았': 215,
#  '어떻': 216,
#  '궁금': 217,
#  '합니다': 218,
#  '동향': 219,
#  '좋': 220,
#  '비교': 221,
#  '해서': 222,
#  '수단': 223,
#  '연령': 224,
#  '볼': 225,
#  '이해': 226,
#  '도움': 227,
#  '만': 228,
#  '미칠': 229,
#  '왜': 230,
#  '관한': 231,
#  '기본': 232,
#  '차이': 233,
#  '이란': 234,
#  '의미': 235,
#  '용어': 236,
#  '인해': 237,
#  '핵심': 238,
#  '파킨슨병': 239,
#  '가지': 240,
#  '특성': 241,
#  '우리': 242,
#  '아': 243,
#  '그리고': 244,
#  '어떻게': 245,
#  '정확히': 246,
#  '기준': 247,
#  '같': 248,
#  '갖': 249,
#  '신경': 250,
#  '면': 251,
#  '구분': 252,
#  '다른지': 253,
#  '명칭': 254,
#  '치료': 255,
#  '보이': 256,
#  '구별': 257,
#  '될까요': 258,
#  '노망': 259,
#  '병인': 260,
#  '경우': 261,
#  '말': 262,
#  '나타날': 263,
#  '비슷': 264,
#  '라고': 265,
#  '식': 266,
#  '동일': 267,
#  '방식': 268,
#  '증세': 269,
#  '맞': 270,
#  '유발': 271,
#  '형태': 272,
#  '내용': 273,
#  '기억력': 274,
#  '감퇴': 275,
#  '단어': 276,
#  '잘': 277,
#  '떠오르': 278,
#  '지': 279,
#  '않': 280,
#  '일상': 281,
#  '생활': 282,
#  '환자': 283,
#  '특히': 284,
#  '대표': 285,
#  '심각': 286,
#  '다면': 287,
#  '초기': 288,
#  '단계': 289,
#  '상': 290,
#  '실증': 291,
#  '아니': 292,
#  '라': 293,
#  '걸렸': 294,
#  '때': 295,
#  '일반인': 296,
#  '흔한': 297,
#  '얼마나': 298,
#  '시간': 299,
#  '가까운': 300,
#  '저하': 301,
#  '일반': 302,
#  '시': 303,
#  '할머니': 304,
#  '동반': 305,
#  '조심': 306,
#  '상실': 307,
#  '잊어버리': 308,
#  '포함': 309,
#  '먼저': 310,
#  '느끼': 311,
#  '생각': 312,
#  '못하': 313,
#  '잃': 314,
#  '해요': 315,
#  '나타날까요': 316,
#  '나타내': 317,
#  '시설': 318,
#  '어디': 319,
#  '상세히': 320,
#  '각각': 321,
#  '절차': 322,
#  '거쳐야': 323,
#  '어야': 324,
#  '느낄': 325,
#  '으려면': 326,
#  '아야': 327,
#  '의한': 328,
#  '함께': 329,
#  '예후': 330,
#  '병원': 331,
#  '의사': 332,
#  '찾': 333,
#  '이루': 334,
#  '약화': 335,
#  '판단': 336,
#  '특이': 337,
#  '부탁드립니다': 338,
#  '경험': 339,
#  '쉬운': 340,
#  '시행': 341,
#  '전문가': 342,
#  '누구': 343,
#  '보통': 344,
#  '이상': 345,
#  '떠올리': 346,
#  '혈액': 347,
#  '중증': 348,
#  '정하': 349,
#  '알츠하이머': 350,
#  'apo': 351,
#  'e': 352,
#  '유전자': 353,
#  '어려움': 354,
#  '조사': 355,
#  '의학': 356,
#  '증도': 357,
#  '전문의': 358,
#  '길': 359,
#  '집': 360,
#  '못': 361,
#  '려면': 362,
#  '찾아가': 363,
#  '야': 364,
#  '기능': 365,
#  '이름': 366,
#  '연락처': 367,
#  '곳': 368,
#  '검색어': 369,
#  '어서': 370,
#  '문진': 371,
#  'ct': 372,
#  '줄': 373,
#  '상담': 374,
#  '원리': 375,
#  '의심': 376,
#  '아버지': 377,
#  '버리': 378,
#  '적절': 379,
#  '찍': 380,
#  '가능': 381,
#  '한지': 382,
#  '평가': 383,
#  '영상': 384,
#  '목적': 385,
#  '통해': 386,
#  '보건소': 387,
#  '소개': 388,
#  '사진': 389,
#  '필수': 390,
#  '진료': 391,
#  '전문': 392,
#  '분야': 393,
#  '어느': 394,
#  '무료': 395,
#  '내원': 396,
#  '아니면': 397,
#  '자기': 398,
#  '공명': 399,
#  '순서': 400,
#  '이루어지': 401,
#  '따라야': 402,
#  '비용': 403,
#  '정도': 404,
#  '기록': 405,
#  '활용': 406,
#  '걸릴까요': 407,
#  '나타났': 408,
#  '조건': 409,
#  '수집': 410,
#  '으면': 411,
#  '보': 412,
#  '메커니즘': 413,
#  '약물': 414,
#  '치료법': 415,
#  '개인': 416,
#  '노력': 417,
#  '근본': 418,
#  '아직': 419,
#  '까지': 420,
#  '없': 421,
#  '목표': 422,
#  '며': 423,
#  '보편': 424,
#  '수술': 425,
#  '시술': 426,
#  '완치': 427,
#  '현재': 428,
#  '줄이': 429,
#  '가족': 430,
#  '소식': 431,
#  '습관': 432,
#  '간헐': 433,
#  '단식': 434,
#  '다양': 435,
#  '후': 436,
#  '예상': 437,
#  '부작용': 438,
#  '보조제': 439,
#  '어떤지': 440,
#  '대안': 441,
#  '서비스': 442,
#  '기대': 443,
#  '개발': 444,
#  '개선': 445,
#  '협력': 446,
#  '다고': 447,
#  '언제': 448,
#  '쯤': 449,
#  '지원': 450,
#  '자연': 451,
#  '요법': 452,
#  '보조': 453,
#  '통제': 454,
#  '전략': 455,
#  '기술': 456,
#  '분': 457,
#  '기간': 458,
#  '접근': 459,
#  '시도': 460,
#  '실천': 461,
#  '재활': 462,
#  '완전히': 463,
#  '다는데': 464,
#  '그런가요': 465,
#  '완화': 466,
#  '시키': 467,
#  '성공률': 468,
#  '식단': 469,
#  '조절': 470,
#  '많': 471,
#  '식이': 472,
#  '추천': 473,
#  '법': 474,
#  '앓': 475,
#  '알코올': 476,
#  '검진': 477,
#  '해석': 478,
#  '센터': 479,
#  '검색': 480,
#  '장소': 481,
#  '잠': 482,
#  '자': 483,
#  '알콜': 484,
#  '테스트': 485,
#  '검': 486,
#  '진': 487,
#  '학과': 488,
#  '소견': 489,
#  '가진': 490,
#  '간단': 491,
#  '서': 492,
#  '유형': 493,
#  '할지': 494,
#  '조언': 495,
#  '술': 496,
#  '예약': 497,
#  '의원': 498,
#  '수면': 499,
#  '심해': 500,
#  '이용': 501,
#  '클리닉': 502,
#  '위치': 503,
#  '조기': 504,
#  '집중력': 505,
#  '떨어지': 506,
#  '유명': 507,
#  '얻': 508,
#  '음주': 509,
#  '잦': 510,
#  '치': 511,
#  '거치': 512,
#  '소요': 513,
#  '전문과': 514,
#  '정확도': 515,
#  '보여': 516,
#  '계신가요': 517,
#  '과다': 518,
#  '요': 519,
#  '발병률': 520,
#  '높일': 521,
#  '꼭': 522,
#  '문의': 523,
#  '적합': 524,
#  '입력': 525,
#  '믿': 526,
#  '없이': 527,
#  '프로그램': 528,
#  '실시': 529,
#  '참고': 530,
#  '오랜': 531,
#  '동안': 532,
#  '특별히': 533,
#  '행동': 534,
#  '과음': 535,
#  '금주': 536,
#  '위험': 537,
#  '최소': 538,
#  '화': 539,
#  '운동': 540,
#  '건강': 541,
#  '식습관': 542,
#  '식품': 543,
#  '영양소': 544,
#  '끊': 545,
#  '가치': 546,
#  '영양가': 547,
#  '음식': 548,
#  '유지': 549,
#  '자제': 550,
#  '취할': 551,
#  '은데': 552,
#  '복용': 553,
#  '마실': 554,
#  '이점': 555,
#  '가져야': 556,
#  '양': 557,
#  '빈도': 558,
#  '접종': 559,
#  '줄일': 560,
#  '음': 561,
#  '주량': 562,
#  '장점': 563,
#  '식사': 564,
#  '전': 565,
#  '적용': 566,
#  '먹': 567,
#  '권고': 568,
#  '환경': 569,
#  '스트레스': 570,
#  '방지': 571,
#  '지켜야': 572,
#  '규칙': 573,
#  '써야': 574,
#  '피하': 575,
#  '금단': 576,
#  '맥주': 577,
#  '예방책': 578,
#  '가질': 579,
#  '도록': 580,
#  '영양제': 581,
#  '마셨': 582,
#  '필름': 583,
#  '끊기': 584,
#  '섭': 585,
#  '취량': 586,
#  '조금': 587,
#  '횟수': 588,
#  '차지': 589,
#  '비율': 590,
#  '높': 591,
#  '은가요': 592,
#  '중독': 593,
#  '을수록': 594,
#  '는지요': 595,
#  '소비': 596,
#  '간': 597,
#  '기여': 598,
#  '이론': 599,
#  '할아버지': 600,
#  '따라': 601,
#  '달라지': 602,
#  '사실': 603,
#  '으로서': 604,
#  '다는': 605,
#  '걸린': 606,
#  '인과': 607,
#  '늦': 608,
#  '악화': 609,
#  '상관': 610,
#  '부분': 611,
#  '주가': 612,
#  '혈관': 613,
#  '상태': 614,
#  '가리키': 615,
#  '의존': 616,
#  '상황': 617,
#  '구체': 618,
#  '그렇': 619,
#  '소비량': 620,
#  '증이': 621,
#  '그것': 622,
#  '두드러지': 623,
#  '관해서': 624,
#  '처음': 625,
#  '경미': 626,
#  '수준': 627,
#  '다가': 628,
#  '점차': 629,
#  '깜박거리': 630,
#  '겪': 631,
#  '블랙아웃': 632,
#  '깜빡': 633,
#  '전날': 634,
#  '흐릿': 635,
#  '평소': 636,
#  '즉시': 637,
#  '중간': 638,
#  '까먹': 639,
#  '지속': 640,
#  '마셔서': 641,
#  '평상시': 642,
#  '표현': 643,
#  '흐려': 644,
#  '정신': 645,
#  '계속': 646,
#  '일': 647,
#  '해당': 648,
#  '깜박': 649,
#  '깜빡하': 650,
#  '지남': 651,
#  '깜빡거리': 652,
#  '대처': 653,
#  '장기간': 654,
#  '가요': 655,
#  '종종': 656,
#  '흐려질': 657,
#  '깜빡깜빡': 658,
#  '볼까요': 659,
#  '흔하': 660,
#  '시킬': 661,
#  '점점': 662,
#  '해질': 663,
#  '경감': 664,
#  '다시': 665,
#  '거쳐서': 666,
#  '고려': 667,
#  '기기': 668,
#  '도구': 669,
#  '준비': 670,
#  '재': 671,
#  '관찰': 672,
#  '마신': 673,
#  '남성': 674,
#  '으셨다면': 675,
#  '질문': 676,
#  '스스로': 677,
#  '안': 678,
#  '뚜렷': 679,
#  '따르': 680,
#  '자료': 681,
#  '격리': 682,
#  '치유': 683,
#  '바꾸': 684,
#  '해결': 685,
#  '보호': 686,
#  '장비': 687,
#  '선택': 688,
#  '다루': 689,
#  '반드시': 690,
#  '높이': 691,
#  '과도': 692,
#  '회복': 693,
#  '취하': 694,
#  '반응': 695,
#  '옵션': 696,
#  '성공': 697,
#  '률': 698,
#  '약': 699,
#  '제한': 700,
#  '대체': 701,
#  '조성': 702,
#  '바꿔야': 703,
#  '합병증': 704,
#  '우울': 705,
#  '감정': 706,
#  '우울증': 707,
#  '걱정': 708,
#  '없앨': 709,
#  '산후': 710,
#  '처방': 711,
#  '세로토닌': 712,
#  '재흡수': 713,
#  '억제제': 714,
#  '빨리': 715,
#  '호전': 716,
#  '해도': 717,
#  '오래': 718,
#  '푸': 719,
#  '록': 720,
#  '틴': 721,
#  '불구': 722,
#  '이러': 723,
#  '두': 724,
#  '동시': 725,
#  '작': 726,
#  '질수록': 727,
#  '빠른': 728,
#  '피해야': 729,
#  '통한': 730,
#  '가져다주': 731,
#  '거부': 732,
#  '복용량': 733,
#  '멍해': 734,
#  '꾸준히': 735,
#  '어도': 736,
#  '기분': 737,
#  '아침': 738,
#  'adhd': 739,
#  '모유': 740,
#  '수유': 741,
#  '몸': 742,
#  '는다면': 743,
#  '임의': 744,
#  '중단': 745,
#  '은지': 746,
#  '안전': 747,
#  '아기': 748,
#  '부정': 749,
#  '공황': 750,
#  '성분': 751,
#  '두통약': 752,
#  '증가': 753,
#  '꾸준': 754,
#  '사라질': 755,
#  '일시': 756,
#  '멈출': 757,
#  '제': 758,
#  '마음대로': 759,
#  '자신': 760,
#  '감': 761,
#  '능력': 762,
#  '향상': 763,
#  '고통': 764,
#  '경구': 765,
#  '용': 766,
#  '말기': 767,
#  '신': 768,
#  '질물': 769,
#  '더라도': 770,
#  '생길': 771,
#  '뇌전증': 772,
#  '미칠까요': 773,
#  '오랫동안': 774,
#  '했': 775,
#  '해소': 776,
#  '항우울제': 777,
#  '알프라졸람': 778,
#  '나빠': 779,
#  '입증': 780,
#  '출산': 781,
#  '혜택': 782,
#  '극복': 783,
#  '장기': 784,
#  '호흡': 785,
#  '증후군': 786,
#  '중지': 787,
#  '괜찮': 788,
#  '걸까요': 789,
#  '막': 790,
#  '옳': 791,
#  '겠': 792,
#  '쓰이': 793,
#  '약효': 794,
#  '야기': 795,
#  '없애': 796,
#  '편': 797,
#  '더뎌': 798,
#  '심해질': 799,
#  '치료제': 800,
#  '진다면': 801,
#  '사라지': 802,
#  '질': 803,
#  '사회': 804,
#  '어려운': 805,
#  '특화': 806,
#  '가져올까요': 807,
#  '조합': 808,
#  '빠르': 809,
#  '증약': 810,
#  '상호': 811,
#  '어려울': 812,
#  '까요': 813,
#  '후유증': 814,
#  '남': 815,
#  '비해': 816,
#  '가져올': 817,
#  '감소': 818,
#  '같이': 819,
#  '일으킬': 820,
#  '미미': 821,
#  '강화': 822,
#  '으면서': 823,
#  '통': 824,
#  '아도': 825,
#  '정서': 826,
#  '발달': 827,
#  '긴': 828,
#  '또는': 829,
#  '사례': 830,
#  '부담': 831,
#  '우려': 832,
#  '시기': 833,
#  '정상': 834,
#  '완쾌': 835,
#  '체중': 836,
#  '줄어들': 837,
#  '제대로': 838,
#  '및': 839,
#  '재발': 840,
#  '된다면': 841,
#  '초래': 842,
#  '영양': 843,
#  '낮': 844,
#  '그러나': 845,
#  '계시': 846,
#  '아닌가요': 847,
#  '유일': 848,
#  '해결책': 849,
#  '갱년기': 850,
#  '자외선': 851,
#  '노출': 852,
#  '피부암': 853,
#  '등': 854,
#  '골다공증': 855,
#  '햇볕': 856,
#  '쬐': 857,
#  '자살': 858,
#  '정신과': 859,
#  '조현': 860,
#  '이어지': 861,
#  '요즘': 862,
#  '외롭': 863,
#  '느낀다면': 864,
#  '외로움': 865,
#  '영향력': 866,
#  '큰지': 867,
#  '만사': 868,
#  '욕': 869,
#  '된다는': 870,
#  '심리': 871,
#  '진다는데': 872,
#  '처럼': 873,
#  '활기차': 874,
#  '힘들': 875,
#  '느껴': 876,
#  '외부': 877,
#  '이후': 878,
#  '연결': 879,
#  '고리': 880,
#  '주된': 881,
#  '이어질': 882,
#  '여야': 883,
#  '현황': 884,
#  '이런': 885,
#  '느껴진다면': 886,
#  '아이': 887,
#  '낳': 888,
#  '내부': 889,
#  '소': 890,
#  '오메가': 891,
#  '3': 892,
#  '지방산': 893,
#  '여성': 894,
#  '폐경': 895,
#  '긍정': 896,
#  '학교': 897,
#  '싫': 898,
#  '음증': 899,
#  '삶': 900,
#  '멍한': 901,
#  '증과': 902,
#  '폐경기': 903,
#  '소아': 904,
#  '과잉': 905,
#  '기복': 906,
#  '충동': 907,
#  '불안': 908,
#  '웃': 909,
#  '으려고': 910,
#  '얼굴': 911,
#  '일부': 912,
#  '산모': 913,
#  '산욕기': 914,
#  '불안감': 915,
#  '불': 916,
#  '죄책감': 917,
#  '느낌': 918,
#  '바닥': 919,
#  '내려가': 920,
#  '호로': 921,
#  '몬': 922,
#  '무기력감': 923,
#  '징후': 924,
#  '상실감': 925,
#  '무력감': 926,
#  '분류': 927,
#  '표정': 928,
#  '변동': 929,
#  '일어날': 930,
#  '드': 931,
#  '성향': 932,
#  '무': 933,
#  '기력': 934,
#  '눈물': 935,
#  '전형': 936,
#  '이것': 937,
#  '안정': 938,
#  '생겨': 939,
#  '살': 940,
#  '갑자기': 941,
#  '피로감': 942,
#  '헌팅': 943,
#  '톤': 944,
#  '병과': 945,
#  '분만': 946,
#  '일치': 947,
#  '딸': 948,
#  '울음': 949,
#  '소리': 950,
#  '짜증': 951,
#  '시달리': 952,
#  '성욕': 953,
#  '복부비만': 954,
#  '함': 955,
#  '6': 956,
#  '개월': 957,
#  '창문': 958,
#  '울': 959,
#  '식은땀': 960,
#  '열감': 961,
#  '을지': 962,
#  '다를까요': 963,
#  '가을': 964,
#  '무기력증': 965,
#  '심하': 966,
#  '나타난': 967,
#  '임신': 968,
#  '차': 969,
#  '식욕': 970,
#  '으며': 971,
#  '오': 972,
#  '하루': 973,
#  '몇': 974,
#  '번': 975,
#  '마음': 976,
#  '허탈감': 977,
#  '월경': 978,
#  '세상': 979,
#  '사': 980,
#  '재미': 981,
#  '긴장': 982,
#  '초조': 983,
#  '늘': 984,
#  '피곤': 985,
#  '졸리': 986,
#  '느껴질': 987,
#  '갑작스러운': 988,
#  '슬픔': 989,
#  '뒤': 990,
#  '자꾸': 991,
#  '혹시': 992,
#  '아닌지': 993,
#  '지난': 994,
#  '슬픈': 995,
#  '허탈': 996,
#  '무기력': 997,
#  '지연': 998,
#  '갑작': 999,
#  ...}

# %%
word_to_idx = vocab
idx_to_word = {i: word for word, i in word_to_idx.items()}

# %%
word_to_idx
# Out:
# {'<PAD>': 0,
#  '<SOS>': 1,
#  '<EOS>': 2,
#  '<UNK>': 3,
#  '알츠하이머병': 4,
#  '의': 5,
#  '원인': 6,
#  '으로': 7,
#  '매일': 8,
#  '소주': 9,
#  '를': 10,
#  '섭취': 11,
#  '하': 12,
#  '는': 13,
#  '것': 14,
#  '이': 15,
#  '언급': 16,
#  '되': 17,
#  '고': 18,
#  '있': 19,
#  '는데': 20,
#  ',': 21,
#  '에': 22,
#  '대한': 23,
#  '근거': 24,
#  '가': 25,
#  '는지': 26,
#  '알려': 27,
#  '주': 28,
#  '세요': 29,
#  '.': 30,
#  '라는': 31,
#  '질병': 32,
#  '은': 33,
#  '유전': 34,
#  '적': 35,
#  '영향': 36,
#  '을': 37,
#  '받': 38,
#  '인가요': 39,
#  '?': 40,
#  '발생': 41,
#  '연구': 42,
#  '나': 43,
#  '발견': 44,
#  '진행': 45,
#  '중': 46,
#  '발병': 47,
#  '과': 48,
#  '관련': 49,
#  '여': 50,
#  '뇌': 51,
#  '노화': 52,
#  '로': 53,
#  '인한': 54,
#  '증상': 55,
#  '된': 56,
#  '결과': 57,
#  '을까요': 58,
#  '무엇': 59,
#  '주요': 60,
#  '예방': 61,
#  '위해': 62,
#  '한': 63,
#  '병': 64,
#  '씩': 65,
#  '권장': 66,
#  '이유': 67,
#  '다른': 68,
#  '들': 69,
#  '대해': 70,
#  '데': 71,
#  '미치': 72,
#  '요인': 73,
#  '어떤': 74,
#  '나요': 75,
#  '치매': 76,
#  '사이': 77,
#  '어떠': 78,
#  '연관': 79,
#  '성': 80,
#  '하나': 81,
#  '인': 82,
#  '대해서': 83,
#  '자세히': 84,
#  '가족력': 85,
#  '이외': 86,
#  '상세': 87,
#  '게': 88,
#  '설명': 89,
#  '해': 90,
#  '그': 91,
#  '따른': 92,
#  '알': 93,
#  '싶': 94,
#  '어요': 95,
#  '과정': 96,
#  '에서': 97,
#  '가장': 98,
#  '문제': 99,
#  '될': 100,
#  '수': 101,
#  '감염': 102,
#  '균': 103,
#  '정의': 104,
#  '와': 105,
#  '특징': 106,
#  '30': 107,
#  '대': 108,
#  '더': 109,
#  '쉽': 110,
#  '찾아볼': 111,
#  '외': 112,
#  '생기': 113,
#  '현상': 114,
#  '차이점': 115,
#  '알려져': 116,
#  '일어나': 117,
#  '큰': 118,
#  '역할': 119,
#  '마시': 120,
#  '란': 121,
#  '습니다': 122,
#  '확인': 123,
#  '기': 124,
#  '의료': 125,
#  '기관': 126,
#  '방문': 127,
#  '해야': 128,
#  '자세': 129,
#  '듣': 130,
#  '중요': 131,
#  '사항': 132,
#  '흔히': 133,
#  '위한': 134,
#  '조치': 135,
#  '예방법': 136,
#  '나이': 137,
#  '젊': 138,
#  '사람': 139,
#  '에게': 140,
#  '도': 141,
#  '많이': 142,
#  '나타나': 143,
#  '알려진': 144,
#  '존재': 145,
#  '40': 146,
#  '세': 147,
#  '인데': 148,
#  '의해': 149,
#  '할': 150,
#  '일으키': 151,
#  '최신': 152,
#  '요소': 153,
#  '걸리': 154,
#  '이나': 155,
#  '신체': 156,
#  '변화': 157,
#  '주의': 158,
#  '가설': 159,
#  '실': 160,
#  '실험': 161,
#  '진단': 162,
#  '검사': 163,
#  '검토': 164,
#  '할까요': 165,
#  '내': 166,
#  '머리': 167,
#  '속': 168,
#  '지우개': 169,
#  '영화': 170,
#  '나오': 171,
#  '일까요': 172,
#  '위해서': 173,
#  '필요': 174,
#  '한가요': 175,
#  '거나': 176,
#  '관리': 177,
#  '취해야': 178,
#  '인지': 179,
#  '관계': 180,
#  '걸릴': 181,
#  '정보': 182,
#  '퇴행': 183,
#  '최근': 184,
#  '었': 185,
#  '방법': 186,
#  '사용': 187,
#  '추가': 188,
#  '종류': 189,
#  '인자': 190,
#  '효과': 191,
#  '기억': 192,
#  '장애': 193,
#  '언어': 194,
#  '서로': 195,
#  '다른가요': 196,
#  '한다면': 197,
#  '공통점': 198,
#  '정확': 199,
#  '의료진': 200,
#  '제공': 201,
#  '질환': 202,
#  '어': 203,
#  '주장': 204,
#  '점': 205,
#  '관여': 206,
#  '유사': 207,
#  '면서': 208,
#  '건가요': 209,
#  '노인': 210,
#  '에게서': 211,
#  '주로': 212,
#  '작용': 213,
#  '자주': 214,
#  '았': 215,
#  '어떻': 216,
#  '궁금': 217,
#  '합니다': 218,
#  '동향': 219,
#  '좋': 220,
#  '비교': 221,
#  '해서': 222,
#  '수단': 223,
#  '연령': 224,
#  '볼': 225,
#  '이해': 226,
#  '도움': 227,
#  '만': 228,
#  '미칠': 229,
#  '왜': 230,
#  '관한': 231,
#  '기본': 232,
#  '차이': 233,
#  '이란': 234,
#  '의미': 235,
#  '용어': 236,
#  '인해': 237,
#  '핵심': 238,
#  '파킨슨병': 239,
#  '가지': 240,
#  '특성': 241,
#  '우리': 242,
#  '아': 243,
#  '그리고': 244,
#  '어떻게': 245,
#  '정확히': 246,
#  '기준': 247,
#  '같': 248,
#  '갖': 249,
#  '신경': 250,
#  '면': 251,
#  '구분': 252,
#  '다른지': 253,
#  '명칭': 254,
#  '치료': 255,
#  '보이': 256,
#  '구별': 257,
#  '될까요': 258,
#  '노망': 259,
#  '병인': 260,
#  '경우': 261,
#  '말': 262,
#  '나타날': 263,
#  '비슷': 264,
#  '라고': 265,
#  '식': 266,
#  '동일': 267,
#  '방식': 268,
#  '증세': 269,
#  '맞': 270,
#  '유발': 271,
#  '형태': 272,
#  '내용': 273,
#  '기억력': 274,
#  '감퇴': 275,
#  '단어': 276,
#  '잘': 277,
#  '떠오르': 278,
#  '지': 279,
#  '않': 280,
#  '일상': 281,
#  '생활': 282,
#  '환자': 283,
#  '특히': 284,
#  '대표': 285,
#  '심각': 286,
#  '다면': 287,
#  '초기': 288,
#  '단계': 289,
#  '상': 290,
#  '실증': 291,
#  '아니': 292,
#  '라': 293,
#  '걸렸': 294,
#  '때': 295,
#  '일반인': 296,
#  '흔한': 297,
#  '얼마나': 298,
#  '시간': 299,
#  '가까운': 300,
#  '저하': 301,
#  '일반': 302,
#  '시': 303,
#  '할머니': 304,
#  '동반': 305,
#  '조심': 306,
#  '상실': 307,
#  '잊어버리': 308,
#  '포함': 309,
#  '먼저': 310,
#  '느끼': 311,
#  '생각': 312,
#  '못하': 313,
#  '잃': 314,
#  '해요': 315,
#  '나타날까요': 316,
#  '나타내': 317,
#  '시설': 318,
#  '어디': 319,
#  '상세히': 320,
#  '각각': 321,
#  '절차': 322,
#  '거쳐야': 323,
#  '어야': 324,
#  '느낄': 325,
#  '으려면': 326,
#  '아야': 327,
#  '의한': 328,
#  '함께': 329,
#  '예후': 330,
#  '병원': 331,
#  '의사': 332,
#  '찾': 333,
#  '이루': 334,
#  '약화': 335,
#  '판단': 336,
#  '특이': 337,
#  '부탁드립니다': 338,
#  '경험': 339,
#  '쉬운': 340,
#  '시행': 341,
#  '전문가': 342,
#  '누구': 343,
#  '보통': 344,
#  '이상': 345,
#  '떠올리': 346,
#  '혈액': 347,
#  '중증': 348,
#  '정하': 349,
#  '알츠하이머': 350,
#  'apo': 351,
#  'e': 352,
#  '유전자': 353,
#  '어려움': 354,
#  '조사': 355,
#  '의학': 356,
#  '증도': 357,
#  '전문의': 358,
#  '길': 359,
#  '집': 360,
#  '못': 361,
#  '려면': 362,
#  '찾아가': 363,
#  '야': 364,
#  '기능': 365,
#  '이름': 366,
#  '연락처': 367,
#  '곳': 368,
#  '검색어': 369,
#  '어서': 370,
#  '문진': 371,
#  'ct': 372,
#  '줄': 373,
#  '상담': 374,
#  '원리': 375,
#  '의심': 376,
#  '아버지': 377,
#  '버리': 378,
#  '적절': 379,
#  '찍': 380,
#  '가능': 381,
#  '한지': 382,
#  '평가': 383,
#  '영상': 384,
#  '목적': 385,
#  '통해': 386,
#  '보건소': 387,
#  '소개': 388,
#  '사진': 389,
#  '필수': 390,
#  '진료': 391,
#  '전문': 392,
#  '분야': 393,
#  '어느': 394,
#  '무료': 395,
#  '내원': 396,
#  '아니면': 397,
#  '자기': 398,
#  '공명': 399,
#  '순서': 400,
#  '이루어지': 401,
#  '따라야': 402,
#  '비용': 403,
#  '정도': 404,
#  '기록': 405,
#  '활용': 406,
#  '걸릴까요': 407,
#  '나타났': 408,
#  '조건': 409,
#  '수집': 410,
#  '으면': 411,
#  '보': 412,
#  '메커니즘': 413,
#  '약물': 414,
#  '치료법': 415,
#  '개인': 416,
#  '노력': 417,
#  '근본': 418,
#  '아직': 419,
#  '까지': 420,
#  '없': 421,
#  '목표': 422,
#  '며': 423,
#  '보편': 424,
#  '수술': 425,
#  '시술': 426,
#  '완치': 427,
#  '현재': 428,
#  '줄이': 429,
#  '가족': 430,
#  '소식': 431,
#  '습관': 432,
#  '간헐': 433,
#  '단식': 434,
#  '다양': 435,
#  '후': 436,
#  '예상': 437,
#  '부작용': 438,
#  '보조제': 439,
#  '어떤지': 440,
#  '대안': 441,
#  '서비스': 442,
#  '기대': 443,
#  '개발': 444,
#  '개선': 445,
#  '협력': 446,
#  '다고': 447,
#  '언제': 448,
#  '쯤': 449,
#  '지원': 450,
#  '자연': 451,
#  '요법': 452,
#  '보조': 453,
#  '통제': 454,
#  '전략': 455,
#  '기술': 456,
#  '분': 457,
#  '기간': 458,
#  '접근': 459,
#  '시도': 460,
#  '실천': 461,
#  '재활': 462,
#  '완전히': 463,
#  '다는데': 464,
#  '그런가요': 465,
#  '완화': 466,
#  '시키': 467,
#  '성공률': 468,
#  '식단': 469,
#  '조절': 470,
#  '많': 471,
#  '식이': 472,
#  '추천': 473,
#  '법': 474,
#  '앓': 475,
#  '알코올': 476,
#  '검진': 477,
#  '해석': 478,
#  '센터': 479,
#  '검색': 480,
#  '장소': 481,
#  '잠': 482,
#  '자': 483,
#  '알콜': 484,
#  '테스트': 485,
#  '검': 486,
#  '진': 487,
#  '학과': 488,
#  '소견': 489,
#  '가진': 490,
#  '간단': 491,
#  '서': 492,
#  '유형': 493,
#  '할지': 494,
#  '조언': 495,
#  '술': 496,
#  '예약': 497,
#  '의원': 498,
#  '수면': 499,
#  '심해': 500,
#  '이용': 501,
#  '클리닉': 502,
#  '위치': 503,
#  '조기': 504,
#  '집중력': 505,
#  '떨어지': 506,
#  '유명': 507,
#  '얻': 508,
#  '음주': 509,
#  '잦': 510,
#  '치': 511,
#  '거치': 512,
#  '소요': 513,
#  '전문과': 514,
#  '정확도': 515,
#  '보여': 516,
#  '계신가요': 517,
#  '과다': 518,
#  '요': 519,
#  '발병률': 520,
#  '높일': 521,
#  '꼭': 522,
#  '문의': 523,
#  '적합': 524,
#  '입력': 525,
#  '믿': 526,
#  '없이': 527,
#  '프로그램': 528,
#  '실시': 529,
#  '참고': 530,
#  '오랜': 531,
#  '동안': 532,
#  '특별히': 533,
#  '행동': 534,
#  '과음': 535,
#  '금주': 536,
#  '위험': 537,
#  '최소': 538,
#  '화': 539,
#  '운동': 540,
#  '건강': 541,
#  '식습관': 542,
#  '식품': 543,
#  '영양소': 544,
#  '끊': 545,
#  '가치': 546,
#  '영양가': 547,
#  '음식': 548,
#  '유지': 549,
#  '자제': 550,
#  '취할': 551,
#  '은데': 552,
#  '복용': 553,
#  '마실': 554,
#  '이점': 555,
#  '가져야': 556,
#  '양': 557,
#  '빈도': 558,
#  '접종': 559,
#  '줄일': 560,
#  '음': 561,
#  '주량': 562,
#  '장점': 563,
#  '식사': 564,
#  '전': 565,
#  '적용': 566,
#  '먹': 567,
#  '권고': 568,
#  '환경': 569,
#  '스트레스': 570,
#  '방지': 571,
#  '지켜야': 572,
#  '규칙': 573,
#  '써야': 574,
#  '피하': 575,
#  '금단': 576,
#  '맥주': 577,
#  '예방책': 578,
#  '가질': 579,
#  '도록': 580,
#  '영양제': 581,
#  '마셨': 582,
#  '필름': 583,
#  '끊기': 584,
#  '섭': 585,
#  '취량': 586,
#  '조금': 587,
#  '횟수': 588,
#  '차지': 589,
#  '비율': 590,
#  '높': 591,
#  '은가요': 592,
#  '중독': 593,
#  '을수록': 594,
#  '는지요': 595,
#  '소비': 596,
#  '간': 597,
#  '기여': 598,
#  '이론': 599,
#  '할아버지': 600,
#  '따라': 601,
#  '달라지': 602,
#  '사실': 603,
#  '으로서': 604,
#  '다는': 605,
#  '걸린': 606,
#  '인과': 607,
#  '늦': 608,
#  '악화': 609,
#  '상관': 610,
#  '부분': 611,
#  '주가': 612,
#  '혈관': 613,
#  '상태': 614,
#  '가리키': 615,
#  '의존': 616,
#  '상황': 617,
#  '구체': 618,
#  '그렇': 619,
#  '소비량': 620,
#  '증이': 621,
#  '그것': 622,
#  '두드러지': 623,
#  '관해서': 624,
#  '처음': 625,
#  '경미': 626,
#  '수준': 627,
#  '다가': 628,
#  '점차': 629,
#  '깜박거리': 630,
#  '겪': 631,
#  '블랙아웃': 632,
#  '깜빡': 633,
#  '전날': 634,
#  '흐릿': 635,
#  '평소': 636,
#  '즉시': 637,
#  '중간': 638,
#  '까먹': 639,
#  '지속': 640,
#  '마셔서': 641,
#  '평상시': 642,
#  '표현': 643,
#  '흐려': 644,
#  '정신': 645,
#  '계속': 646,
#  '일': 647,
#  '해당': 648,
#  '깜박': 649,
#  '깜빡하': 650,
#  '지남': 651,
#  '깜빡거리': 652,
#  '대처': 653,
#  '장기간': 654,
#  '가요': 655,
#  '종종': 656,
#  '흐려질': 657,
#  '깜빡깜빡': 658,
#  '볼까요': 659,
#  '흔하': 660,
#  '시킬': 661,
#  '점점': 662,
#  '해질': 663,
#  '경감': 664,
#  '다시': 665,
#  '거쳐서': 666,
#  '고려': 667,
#  '기기': 668,
#  '도구': 669,
#  '준비': 670,
#  '재': 671,
#  '관찰': 672,
#  '마신': 673,
#  '남성': 674,
#  '으셨다면': 675,
#  '질문': 676,
#  '스스로': 677,
#  '안': 678,
#  '뚜렷': 679,
#  '따르': 680,
#  '자료': 681,
#  '격리': 682,
#  '치유': 683,
#  '바꾸': 684,
#  '해결': 685,
#  '보호': 686,
#  '장비': 687,
#  '선택': 688,
#  '다루': 689,
#  '반드시': 690,
#  '높이': 691,
#  '과도': 692,
#  '회복': 693,
#  '취하': 694,
#  '반응': 695,
#  '옵션': 696,
#  '성공': 697,
#  '률': 698,
#  '약': 699,
#  '제한': 700,
#  '대체': 701,
#  '조성': 702,
#  '바꿔야': 703,
#  '합병증': 704,
#  '우울': 705,
#  '감정': 706,
#  '우울증': 707,
#  '걱정': 708,
#  '없앨': 709,
#  '산후': 710,
#  '처방': 711,
#  '세로토닌': 712,
#  '재흡수': 713,
#  '억제제': 714,
#  '빨리': 715,
#  '호전': 716,
#  '해도': 717,
#  '오래': 718,
#  '푸': 719,
#  '록': 720,
#  '틴': 721,
#  '불구': 722,
#  '이러': 723,
#  '두': 724,
#  '동시': 725,
#  '작': 726,
#  '질수록': 727,
#  '빠른': 728,
#  '피해야': 729,
#  '통한': 730,
#  '가져다주': 731,
#  '거부': 732,
#  '복용량': 733,
#  '멍해': 734,
#  '꾸준히': 735,
#  '어도': 736,
#  '기분': 737,
#  '아침': 738,
#  'adhd': 739,
#  '모유': 740,
#  '수유': 741,
#  '몸': 742,
#  '는다면': 743,
#  '임의': 744,
#  '중단': 745,
#  '은지': 746,
#  '안전': 747,
#  '아기': 748,
#  '부정': 749,
#  '공황': 750,
#  '성분': 751,
#  '두통약': 752,
#  '증가': 753,
#  '꾸준': 754,
#  '사라질': 755,
#  '일시': 756,
#  '멈출': 757,
#  '제': 758,
#  '마음대로': 759,
#  '자신': 760,
#  '감': 761,
#  '능력': 762,
#  '향상': 763,
#  '고통': 764,
#  '경구': 765,
#  '용': 766,
#  '말기': 767,
#  '신': 768,
#  '질물': 769,
#  '더라도': 770,
#  '생길': 771,
#  '뇌전증': 772,
#  '미칠까요': 773,
#  '오랫동안': 774,
#  '했': 775,
#  '해소': 776,
#  '항우울제': 777,
#  '알프라졸람': 778,
#  '나빠': 779,
#  '입증': 780,
#  '출산': 781,
#  '혜택': 782,
#  '극복': 783,
#  '장기': 784,
#  '호흡': 785,
#  '증후군': 786,
#  '중지': 787,
#  '괜찮': 788,
#  '걸까요': 789,
#  '막': 790,
#  '옳': 791,
#  '겠': 792,
#  '쓰이': 793,
#  '약효': 794,
#  '야기': 795,
#  '없애': 796,
#  '편': 797,
#  '더뎌': 798,
#  '심해질': 799,
#  '치료제': 800,
#  '진다면': 801,
#  '사라지': 802,
#  '질': 803,
#  '사회': 804,
#  '어려운': 805,
#  '특화': 806,
#  '가져올까요': 807,
#  '조합': 808,
#  '빠르': 809,
#  '증약': 810,
#  '상호': 811,
#  '어려울': 812,
#  '까요': 813,
#  '후유증': 814,
#  '남': 815,
#  '비해': 816,
#  '가져올': 817,
#  '감소': 818,
#  '같이': 819,
#  '일으킬': 820,
#  '미미': 821,
#  '강화': 822,
#  '으면서': 823,
#  '통': 824,
#  '아도': 825,
#  '정서': 826,
#  '발달': 827,
#  '긴': 828,
#  '또는': 829,
#  '사례': 830,
#  '부담': 831,
#  '우려': 832,
#  '시기': 833,
#  '정상': 834,
#  '완쾌': 835,
#  '체중': 836,
#  '줄어들': 837,
#  '제대로': 838,
#  '및': 839,
#  '재발': 840,
#  '된다면': 841,
#  '초래': 842,
#  '영양': 843,
#  '낮': 844,
#  '그러나': 845,
#  '계시': 846,
#  '아닌가요': 847,
#  '유일': 848,
#  '해결책': 849,
#  '갱년기': 850,
#  '자외선': 851,
#  '노출': 852,
#  '피부암': 853,
#  '등': 854,
#  '골다공증': 855,
#  '햇볕': 856,
#  '쬐': 857,
#  '자살': 858,
#  '정신과': 859,
#  '조현': 860,
#  '이어지': 861,
#  '요즘': 862,
#  '외롭': 863,
#  '느낀다면': 864,
#  '외로움': 865,
#  '영향력': 866,
#  '큰지': 867,
#  '만사': 868,
#  '욕': 869,
#  '된다는': 870,
#  '심리': 871,
#  '진다는데': 872,
#  '처럼': 873,
#  '활기차': 874,
#  '힘들': 875,
#  '느껴': 876,
#  '외부': 877,
#  '이후': 878,
#  '연결': 879,
#  '고리': 880,
#  '주된': 881,
#  '이어질': 882,
#  '여야': 883,
#  '현황': 884,
#  '이런': 885,
#  '느껴진다면': 886,
#  '아이': 887,
#  '낳': 888,
#  '내부': 889,
#  '소': 890,
#  '오메가': 891,
#  '3': 892,
#  '지방산': 893,
#  '여성': 894,
#  '폐경': 895,
#  '긍정': 896,
#  '학교': 897,
#  '싫': 898,
#  '음증': 899,
#  '삶': 900,
#  '멍한': 901,
#  '증과': 902,
#  '폐경기': 903,
#  '소아': 904,
#  '과잉': 905,
#  '기복': 906,
#  '충동': 907,
#  '불안': 908,
#  '웃': 909,
#  '으려고': 910,
#  '얼굴': 911,
#  '일부': 912,
#  '산모': 913,
#  '산욕기': 914,
#  '불안감': 915,
#  '불': 916,
#  '죄책감': 917,
#  '느낌': 918,
#  '바닥': 919,
#  '내려가': 920,
#  '호로': 921,
#  '몬': 922,
#  '무기력감': 923,
#  '징후': 924,
#  '상실감': 925,
#  '무력감': 926,
#  '분류': 927,
#  '표정': 928,
#  '변동': 929,
#  '일어날': 930,
#  '드': 931,
#  '성향': 932,
#  '무': 933,
#  '기력': 934,
#  '눈물': 935,
#  '전형': 936,
#  '이것': 937,
#  '안정': 938,
#  '생겨': 939,
#  '살': 940,
#  '갑자기': 941,
#  '피로감': 942,
#  '헌팅': 943,
#  '톤': 944,
#  '병과': 945,
#  '분만': 946,
#  '일치': 947,
#  '딸': 948,
#  '울음': 949,
#  '소리': 950,
#  '짜증': 951,
#  '시달리': 952,
#  '성욕': 953,
#  '복부비만': 954,
#  '함': 955,
#  '6': 956,
#  '개월': 957,
#  '창문': 958,
#  '울': 959,
#  '식은땀': 960,
#  '열감': 961,
#  '을지': 962,
#  '다를까요': 963,
#  '가을': 964,
#  '무기력증': 965,
#  '심하': 966,
#  '나타난': 967,
#  '임신': 968,
#  '차': 969,
#  '식욕': 970,
#  '으며': 971,
#  '오': 972,
#  '하루': 973,
#  '몇': 974,
#  '번': 975,
#  '마음': 976,
#  '허탈감': 977,
#  '월경': 978,
#  '세상': 979,
#  '사': 980,
#  '재미': 981,
#  '긴장': 982,
#  '초조': 983,
#  '늘': 984,
#  '피곤': 985,
#  '졸리': 986,
#  '느껴질': 987,
#  '갑작스러운': 988,
#  '슬픔': 989,
#  '뒤': 990,
#  '자꾸': 991,
#  '혹시': 992,
#  '아닌지': 993,
#  '지난': 994,
#  '슬픈': 995,
#  '허탈': 996,
#  '무기력': 997,
#  '지연': 998,
#  '갑작': 999,
#  ...}

# %%
idx_to_word
# Out:
# {0: '<PAD>',
#  1: '<SOS>',
#  2: '<EOS>',
#  3: '<UNK>',
#  4: '알츠하이머병',
#  5: '의',
#  6: '원인',
#  7: '으로',
#  8: '매일',
#  9: '소주',
#  10: '를',
#  11: '섭취',
#  12: '하',
#  13: '는',
#  14: '것',
#  15: '이',
#  16: '언급',
#  17: '되',
#  18: '고',
#  19: '있',
#  20: '는데',
#  21: ',',
#  22: '에',
#  23: '대한',
#  24: '근거',
#  25: '가',
#  26: '는지',
#  27: '알려',
#  28: '주',
#  29: '세요',
#  30: '.',
#  31: '라는',
#  32: '질병',
#  33: '은',
#  34: '유전',
#  35: '적',
#  36: '영향',
#  37: '을',
#  38: '받',
#  39: '인가요',
#  40: '?',
#  41: '발생',
#  42: '연구',
#  43: '나',
#  44: '발견',
#  45: '진행',
#  46: '중',
#  47: '발병',
#  48: '과',
#  49: '관련',
#  50: '여',
#  51: '뇌',
#  52: '노화',
#  53: '로',
#  54: '인한',
#  55: '증상',
#  56: '된',
#  57: '결과',
#  58: '을까요',
#  59: '무엇',
#  60: '주요',
#  61: '예방',
#  62: '위해',
#  63: '한',
#  64: '병',
#  65: '씩',
#  66: '권장',
#  67: '이유',
#  68: '다른',
#  69: '들',
#  70: '대해',
#  71: '데',
#  72: '미치',
#  73: '요인',
#  74: '어떤',
#  75: '나요',
#  76: '치매',
#  77: '사이',
#  78: '어떠',
#  79: '연관',
#  80: '성',
#  81: '하나',
#  82: '인',
#  83: '대해서',
#  84: '자세히',
#  85: '가족력',
#  86: '이외',
#  87: '상세',
#  88: '게',
#  89: '설명',
#  90: '해',
#  91: '그',
#  92: '따른',
#  93: '알',
#  94: '싶',
#  95: '어요',
#  96: '과정',
#  97: '에서',
#  98: '가장',
#  99: '문제',
#  100: '될',
#  101: '수',
#  102: '감염',
#  103: '균',
#  104: '정의',
#  105: '와',
#  106: '특징',
#  107: '30',
#  108: '대',
#  109: '더',
#  110: '쉽',
#  111: '찾아볼',
#  112: '외',
#  113: '생기',
#  114: '현상',
#  115: '차이점',
#  116: '알려져',
#  117: '일어나',
#  118: '큰',
#  119: '역할',
#  120: '마시',
#  121: '란',
#  122: '습니다',
#  123: '확인',
#  124: '기',
#  125: '의료',
#  126: '기관',
#  127: '방문',
#  128: '해야',
#  129: '자세',
#  130: '듣',
#  131: '중요',
#  132: '사항',
#  133: '흔히',
#  134: '위한',
#  135: '조치',
#  136: '예방법',
#  137: '나이',
#  138: '젊',
#  139: '사람',
#  140: '에게',
#  141: '도',
#  142: '많이',
#  143: '나타나',
#  144: '알려진',
#  145: '존재',
#  146: '40',
#  147: '세',
#  148: '인데',
#  149: '의해',
#  150: '할',
#  151: '일으키',
#  152: '최신',
#  153: '요소',
#  154: '걸리',
#  155: '이나',
#  156: '신체',
#  157: '변화',
#  158: '주의',
#  159: '가설',
#  160: '실',
#  161: '실험',
#  162: '진단',
#  163: '검사',
#  164: '검토',
#  165: '할까요',
#  166: '내',
#  167: '머리',
#  168: '속',
#  169: '지우개',
#  170: '영화',
#  171: '나오',
#  172: '일까요',
#  173: '위해서',
#  174: '필요',
#  175: '한가요',
#  176: '거나',
#  177: '관리',
#  178: '취해야',
#  179: '인지',
#  180: '관계',
#  181: '걸릴',
#  182: '정보',
#  183: '퇴행',
#  184: '최근',
#  185: '었',
#  186: '방법',
#  187: '사용',
#  188: '추가',
#  189: '종류',
#  190: '인자',
#  191: '효과',
#  192: '기억',
#  193: '장애',
#  194: '언어',
#  195: '서로',
#  196: '다른가요',
#  197: '한다면',
#  198: '공통점',
#  199: '정확',
#  200: '의료진',
#  201: '제공',
#  202: '질환',
#  203: '어',
#  204: '주장',
#  205: '점',
#  206: '관여',
#  207: '유사',
#  208: '면서',
#  209: '건가요',
#  210: '노인',
#  211: '에게서',
#  212: '주로',
#  213: '작용',
#  214: '자주',
#  215: '았',
#  216: '어떻',
#  217: '궁금',
#  218: '합니다',
#  219: '동향',
#  220: '좋',
#  221: '비교',
#  222: '해서',
#  223: '수단',
#  224: '연령',
#  225: '볼',
#  226: '이해',
#  227: '도움',
#  228: '만',
#  229: '미칠',
#  230: '왜',
#  231: '관한',
#  232: '기본',
#  233: '차이',
#  234: '이란',
#  235: '의미',
#  236: '용어',
#  237: '인해',
#  238: '핵심',
#  239: '파킨슨병',
#  240: '가지',
#  241: '특성',
#  242: '우리',
#  243: '아',
#  244: '그리고',
#  245: '어떻게',
#  246: '정확히',
#  247: '기준',
#  248: '같',
#  249: '갖',
#  250: '신경',
#  251: '면',
#  252: '구분',
#  253: '다른지',
#  254: '명칭',
#  255: '치료',
#  256: '보이',
#  257: '구별',
#  258: '될까요',
#  259: '노망',
#  260: '병인',
#  261: '경우',
#  262: '말',
#  263: '나타날',
#  264: '비슷',
#  265: '라고',
#  266: '식',
#  267: '동일',
#  268: '방식',
#  269: '증세',
#  270: '맞',
#  271: '유발',
#  272: '형태',
#  273: '내용',
#  274: '기억력',
#  275: '감퇴',
#  276: '단어',
#  277: '잘',
#  278: '떠오르',
#  279: '지',
#  280: '않',
#  281: '일상',
#  282: '생활',
#  283: '환자',
#  284: '특히',
#  285: '대표',
#  286: '심각',
#  287: '다면',
#  288: '초기',
#  289: '단계',
#  290: '상',
#  291: '실증',
#  292: '아니',
#  293: '라',
#  294: '걸렸',
#  295: '때',
#  296: '일반인',
#  297: '흔한',
#  298: '얼마나',
#  299: '시간',
#  300: '가까운',
#  301: '저하',
#  302: '일반',
#  303: '시',
#  304: '할머니',
#  305: '동반',
#  306: '조심',
#  307: '상실',
#  308: '잊어버리',
#  309: '포함',
#  310: '먼저',
#  311: '느끼',
#  312: '생각',
#  313: '못하',
#  314: '잃',
#  315: '해요',
#  316: '나타날까요',
#  317: '나타내',
#  318: '시설',
#  319: '어디',
#  320: '상세히',
#  321: '각각',
#  322: '절차',
#  323: '거쳐야',
#  324: '어야',
#  325: '느낄',
#  326: '으려면',
#  327: '아야',
#  328: '의한',
#  329: '함께',
#  330: '예후',
#  331: '병원',
#  332: '의사',
#  333: '찾',
#  334: '이루',
#  335: '약화',
#  336: '판단',
#  337: '특이',
#  338: '부탁드립니다',
#  339: '경험',
#  340: '쉬운',
#  341: '시행',
#  342: '전문가',
#  343: '누구',
#  344: '보통',
#  345: '이상',
#  346: '떠올리',
#  347: '혈액',
#  348: '중증',
#  349: '정하',
#  350: '알츠하이머',
#  351: 'apo',
#  352: 'e',
#  353: '유전자',
#  354: '어려움',
#  355: '조사',
#  356: '의학',
#  357: '증도',
#  358: '전문의',
#  359: '길',
#  360: '집',
#  361: '못',
#  362: '려면',
#  363: '찾아가',
#  364: '야',
#  365: '기능',
#  366: '이름',
#  367: '연락처',
#  368: '곳',
#  369: '검색어',
#  370: '어서',
#  371: '문진',
#  372: 'ct',
#  373: '줄',
#  374: '상담',
#  375: '원리',
#  376: '의심',
#  377: '아버지',
#  378: '버리',
#  379: '적절',
#  380: '찍',
#  381: '가능',
#  382: '한지',
#  383: '평가',
#  384: '영상',
#  385: '목적',
#  386: '통해',
#  387: '보건소',
#  388: '소개',
#  389: '사진',
#  390: '필수',
#  391: '진료',
#  392: '전문',
#  393: '분야',
#  394: '어느',
#  395: '무료',
#  396: '내원',
#  397: '아니면',
#  398: '자기',
#  399: '공명',
#  400: '순서',
#  401: '이루어지',
#  402: '따라야',
#  403: '비용',
#  404: '정도',
#  405: '기록',
#  406: '활용',
#  407: '걸릴까요',
#  408: '나타났',
#  409: '조건',
#  410: '수집',
#  411: '으면',
#  412: '보',
#  413: '메커니즘',
#  414: '약물',
#  415: '치료법',
#  416: '개인',
#  417: '노력',
#  418: '근본',
#  419: '아직',
#  420: '까지',
#  421: '없',
#  422: '목표',
#  423: '며',
#  424: '보편',
#  425: '수술',
#  426: '시술',
#  427: '완치',
#  428: '현재',
#  429: '줄이',
#  430: '가족',
#  431: '소식',
#  432: '습관',
#  433: '간헐',
#  434: '단식',
#  435: '다양',
#  436: '후',
#  437: '예상',
#  438: '부작용',
#  439: '보조제',
#  440: '어떤지',
#  441: '대안',
#  442: '서비스',
#  443: '기대',
#  444: '개발',
#  445: '개선',
#  446: '협력',
#  447: '다고',
#  448: '언제',
#  449: '쯤',
#  450: '지원',
#  451: '자연',
#  452: '요법',
#  453: '보조',
#  454: '통제',
#  455: '전략',
#  456: '기술',
#  457: '분',
#  458: '기간',
#  459: '접근',
#  460: '시도',
#  461: '실천',
#  462: '재활',
#  463: '완전히',
#  464: '다는데',
#  465: '그런가요',
#  466: '완화',
#  467: '시키',
#  468: '성공률',
#  469: '식단',
#  470: '조절',
#  471: '많',
#  472: '식이',
#  473: '추천',
#  474: '법',
#  475: '앓',
#  476: '알코올',
#  477: '검진',
#  478: '해석',
#  479: '센터',
#  480: '검색',
#  481: '장소',
#  482: '잠',
#  483: '자',
#  484: '알콜',
#  485: '테스트',
#  486: '검',
#  487: '진',
#  488: '학과',
#  489: '소견',
#  490: '가진',
#  491: '간단',
#  492: '서',
#  493: '유형',
#  494: '할지',
#  495: '조언',
#  496: '술',
#  497: '예약',
#  498: '의원',
#  499: '수면',
#  500: '심해',
#  501: '이용',
#  502: '클리닉',
#  503: '위치',
#  504: '조기',
#  505: '집중력',
#  506: '떨어지',
#  507: '유명',
#  508: '얻',
#  509: '음주',
#  510: '잦',
#  511: '치',
#  512: '거치',
#  513: '소요',
#  514: '전문과',
#  515: '정확도',
#  516: '보여',
#  517: '계신가요',
#  518: '과다',
#  519: '요',
#  520: '발병률',
#  521: '높일',
#  522: '꼭',
#  523: '문의',
#  524: '적합',
#  525: '입력',
#  526: '믿',
#  527: '없이',
#  528: '프로그램',
#  529: '실시',
#  530: '참고',
#  531: '오랜',
#  532: '동안',
#  533: '특별히',
#  534: '행동',
#  535: '과음',
#  536: '금주',
#  537: '위험',
#  538: '최소',
#  539: '화',
#  540: '운동',
#  541: '건강',
#  542: '식습관',
#  543: '식품',
#  544: '영양소',
#  545: '끊',
#  546: '가치',
#  547: '영양가',
#  548: '음식',
#  549: '유지',
#  550: '자제',
#  551: '취할',
#  552: '은데',
#  553: '복용',
#  554: '마실',
#  555: '이점',
#  556: '가져야',
#  557: '양',
#  558: '빈도',
#  559: '접종',
#  560: '줄일',
#  561: '음',
#  562: '주량',
#  563: '장점',
#  564: '식사',
#  565: '전',
#  566: '적용',
#  567: '먹',
#  568: '권고',
#  569: '환경',
#  570: '스트레스',
#  571: '방지',
#  572: '지켜야',
#  573: '규칙',
#  574: '써야',
#  575: '피하',
#  576: '금단',
#  577: '맥주',
#  578: '예방책',
#  579: '가질',
#  580: '도록',
#  581: '영양제',
#  582: '마셨',
#  583: '필름',
#  584: '끊기',
#  585: '섭',
#  586: '취량',
#  587: '조금',
#  588: '횟수',
#  589: '차지',
#  590: '비율',
#  591: '높',
#  592: '은가요',
#  593: '중독',
#  594: '을수록',
#  595: '는지요',
#  596: '소비',
#  597: '간',
#  598: '기여',
#  599: '이론',
#  600: '할아버지',
#  601: '따라',
#  602: '달라지',
#  603: '사실',
#  604: '으로서',
#  605: '다는',
#  606: '걸린',
#  607: '인과',
#  608: '늦',
#  609: '악화',
#  610: '상관',
#  611: '부분',
#  612: '주가',
#  613: '혈관',
#  614: '상태',
#  615: '가리키',
#  616: '의존',
#  617: '상황',
#  618: '구체',
#  619: '그렇',
#  620: '소비량',
#  621: '증이',
#  622: '그것',
#  623: '두드러지',
#  624: '관해서',
#  625: '처음',
#  626: '경미',
#  627: '수준',
#  628: '다가',
#  629: '점차',
#  630: '깜박거리',
#  631: '겪',
#  632: '블랙아웃',
#  633: '깜빡',
#  634: '전날',
#  635: '흐릿',
#  636: '평소',
#  637: '즉시',
#  638: '중간',
#  639: '까먹',
#  640: '지속',
#  641: '마셔서',
#  642: '평상시',
#  643: '표현',
#  644: '흐려',
#  645: '정신',
#  646: '계속',
#  647: '일',
#  648: '해당',
#  649: '깜박',
#  650: '깜빡하',
#  651: '지남',
#  652: '깜빡거리',
#  653: '대처',
#  654: '장기간',
#  655: '가요',
#  656: '종종',
#  657: '흐려질',
#  658: '깜빡깜빡',
#  659: '볼까요',
#  660: '흔하',
#  661: '시킬',
#  662: '점점',
#  663: '해질',
#  664: '경감',
#  665: '다시',
#  666: '거쳐서',
#  667: '고려',
#  668: '기기',
#  669: '도구',
#  670: '준비',
#  671: '재',
#  672: '관찰',
#  673: '마신',
#  674: '남성',
#  675: '으셨다면',
#  676: '질문',
#  677: '스스로',
#  678: '안',
#  679: '뚜렷',
#  680: '따르',
#  681: '자료',
#  682: '격리',
#  683: '치유',
#  684: '바꾸',
#  685: '해결',
#  686: '보호',
#  687: '장비',
#  688: '선택',
#  689: '다루',
#  690: '반드시',
#  691: '높이',
#  692: '과도',
#  693: '회복',
#  694: '취하',
#  695: '반응',
#  696: '옵션',
#  697: '성공',
#  698: '률',
#  699: '약',
#  700: '제한',
#  701: '대체',
#  702: '조성',
#  703: '바꿔야',
#  704: '합병증',
#  705: '우울',
#  706: '감정',
#  707: '우울증',
#  708: '걱정',
#  709: '없앨',
#  710: '산후',
#  711: '처방',
#  712: '세로토닌',
#  713: '재흡수',
#  714: '억제제',
#  715: '빨리',
#  716: '호전',
#  717: '해도',
#  718: '오래',
#  719: '푸',
#  720: '록',
#  721: '틴',
#  722: '불구',
#  723: '이러',
#  724: '두',
#  725: '동시',
#  726: '작',
#  727: '질수록',
#  728: '빠른',
#  729: '피해야',
#  730: '통한',
#  731: '가져다주',
#  732: '거부',
#  733: '복용량',
#  734: '멍해',
#  735: '꾸준히',
#  736: '어도',
#  737: '기분',
#  738: '아침',
#  739: 'adhd',
#  740: '모유',
#  741: '수유',
#  742: '몸',
#  743: '는다면',
#  744: '임의',
#  745: '중단',
#  746: '은지',
#  747: '안전',
#  748: '아기',
#  749: '부정',
#  750: '공황',
#  751: '성분',
#  752: '두통약',
#  753: '증가',
#  754: '꾸준',
#  755: '사라질',
#  756: '일시',
#  757: '멈출',
#  758: '제',
#  759: '마음대로',
#  760: '자신',
#  761: '감',
#  762: '능력',
#  763: '향상',
#  764: '고통',
#  765: '경구',
#  766: '용',
#  767: '말기',
#  768: '신',
#  769: '질물',
#  770: '더라도',
#  771: '생길',
#  772: '뇌전증',
#  773: '미칠까요',
#  774: '오랫동안',
#  775: '했',
#  776: '해소',
#  777: '항우울제',
#  778: '알프라졸람',
#  779: '나빠',
#  780: '입증',
#  781: '출산',
#  782: '혜택',
#  783: '극복',
#  784: '장기',
#  785: '호흡',
#  786: '증후군',
#  787: '중지',
#  788: '괜찮',
#  789: '걸까요',
#  790: '막',
#  791: '옳',
#  792: '겠',
#  793: '쓰이',
#  794: '약효',
#  795: '야기',
#  796: '없애',
#  797: '편',
#  798: '더뎌',
#  799: '심해질',
#  800: '치료제',
#  801: '진다면',
#  802: '사라지',
#  803: '질',
#  804: '사회',
#  805: '어려운',
#  806: '특화',
#  807: '가져올까요',
#  808: '조합',
#  809: '빠르',
#  810: '증약',
#  811: '상호',
#  812: '어려울',
#  813: '까요',
#  814: '후유증',
#  815: '남',
#  816: '비해',
#  817: '가져올',
#  818: '감소',
#  819: '같이',
#  820: '일으킬',
#  821: '미미',
#  822: '강화',
#  823: '으면서',
#  824: '통',
#  825: '아도',
#  826: '정서',
#  827: '발달',
#  828: '긴',
#  829: '또는',
#  830: '사례',
#  831: '부담',
#  832: '우려',
#  833: '시기',
#  834: '정상',
#  835: '완쾌',
#  836: '체중',
#  837: '줄어들',
#  838: '제대로',
#  839: '및',
#  840: '재발',
#  841: '된다면',
#  842: '초래',
#  843: '영양',
#  844: '낮',
#  845: '그러나',
#  846: '계시',
#  847: '아닌가요',
#  848: '유일',
#  849: '해결책',
#  850: '갱년기',
#  851: '자외선',
#  852: '노출',
#  853: '피부암',
#  854: '등',
#  855: '골다공증',
#  856: '햇볕',
#  857: '쬐',
#  858: '자살',
#  859: '정신과',
#  860: '조현',
#  861: '이어지',
#  862: '요즘',
#  863: '외롭',
#  864: '느낀다면',
#  865: '외로움',
#  866: '영향력',
#  867: '큰지',
#  868: '만사',
#  869: '욕',
#  870: '된다는',
#  871: '심리',
#  872: '진다는데',
#  873: '처럼',
#  874: '활기차',
#  875: '힘들',
#  876: '느껴',
#  877: '외부',
#  878: '이후',
#  879: '연결',
#  880: '고리',
#  881: '주된',
#  882: '이어질',
#  883: '여야',
#  884: '현황',
#  885: '이런',
#  886: '느껴진다면',
#  887: '아이',
#  888: '낳',
#  889: '내부',
#  890: '소',
#  891: '오메가',
#  892: '3',
#  893: '지방산',
#  894: '여성',
#  895: '폐경',
#  896: '긍정',
#  897: '학교',
#  898: '싫',
#  899: '음증',
#  900: '삶',
#  901: '멍한',
#  902: '증과',
#  903: '폐경기',
#  904: '소아',
#  905: '과잉',
#  906: '기복',
#  907: '충동',
#  908: '불안',
#  909: '웃',
#  910: '으려고',
#  911: '얼굴',
#  912: '일부',
#  913: '산모',
#  914: '산욕기',
#  915: '불안감',
#  916: '불',
#  917: '죄책감',
#  918: '느낌',
#  919: '바닥',
#  920: '내려가',
#  921: '호로',
#  922: '몬',
#  923: '무기력감',
#  924: '징후',
#  925: '상실감',
#  926: '무력감',
#  927: '분류',
#  928: '표정',
#  929: '변동',
#  930: '일어날',
#  931: '드',
#  932: '성향',
#  933: '무',
#  934: '기력',
#  935: '눈물',
#  936: '전형',
#  937: '이것',
#  938: '안정',
#  939: '생겨',
#  940: '살',
#  941: '갑자기',
#  942: '피로감',
#  943: '헌팅',
#  944: '톤',
#  945: '병과',
#  946: '분만',
#  947: '일치',
#  948: '딸',
#  949: '울음',
#  950: '소리',
#  951: '짜증',
#  952: '시달리',
#  953: '성욕',
#  954: '복부비만',
#  955: '함',
#  956: '6',
#  957: '개월',
#  958: '창문',
#  959: '울',
#  960: '식은땀',
#  961: '열감',
#  962: '을지',
#  963: '다를까요',
#  964: '가을',
#  965: '무기력증',
#  966: '심하',
#  967: '나타난',
#  968: '임신',
#  969: '차',
#  970: '식욕',
#  971: '으며',
#  972: '오',
#  973: '하루',
#  974: '몇',
#  975: '번',
#  976: '마음',
#  977: '허탈감',
#  978: '월경',
#  979: '세상',
#  980: '사',
#  981: '재미',
#  982: '긴장',
#  983: '초조',
#  984: '늘',
#  985: '피곤',
#  986: '졸리',
#  987: '느껴질',
#  988: '갑작스러운',
#  989: '슬픔',
#  990: '뒤',
#  991: '자꾸',
#  992: '혹시',
#  993: '아닌지',
#  994: '지난',
#  995: '슬픈',
#  996: '허탈',
#  997: '무기력',
#  998: '지연',
#  999: '갑작',
#  ...}

# %%
word_to_idx['지연']
# Out:
# 998

# %%
idx_to_word[998]
# Out:
# '지연'

# %%
vocab_size = len(vocab)
vocab_size
# Out:
# 5030

# %%
encoder = EncoderLSTM(vocab_size, hidden_size).to(device)
decoder = AttentionDecoderLSTM(hidden_size, vocab_size).to(device)

# %%
class Seq2SeqWithAttention(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2SeqWithAttention, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

# %%
attention = Seq2SeqWithAttention(encoder, decoder)

# %%
encoder_optimizer = optim.Adam(attention.encoder.parameters(), lr=0.001)
decoder_optimizer = optim.Adam(attention.decoder.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# %%
pairs = [list(x) for x in zip(df['Encoder Inputs'], df['Decoder Inputs'])]

# %%
pairs[1]
# Out:
# ['알츠하이머병이라는 질병은 유전적 영향을 받는 것인가요?',
#  '알츠하이머병은 현재까지 완전한 원인이 밝혀지지 않았습니다.알츠하이머병은 아직 완전히 이해되지 않았지만, 연구 결과에 따르면 유전적인 요소와 다양한 환경적인 요인이 이 질환을 일으키는 역할을 한다고 알려져 있습니다. 특히, 아밀로이드 베타 단백질의 비정상적인 축적이 알츠하이머병과 관련이 있는 것으로 알려져 있습니다. 이 외에도 나이, 노화, 고혈압, 당뇨병, 그리고 흡연 등과 같은 다른 요인들도 알츠하이머병 발병과 연관성이 있을 수 있습니다.더 많은 연구와 조사를 통해 알츠하이머병의 원인을 파악하고 예방 방법을 개발할 필요가 있습니다.']

# %%
idx_to_word[407]
# Out:
# '걸릴까요'

# %%
attention.encoder.train()
attention.decoder.train()
for epoch in range(4):
    trainIters(attention.encoder, attention.decoder, 6000, 1000)
    torch.save(attention.state_dict(), f'attention-chatbot-epoch-{epoch}.pt')
# Out:
# Iteration : 1000, Loss :  3.9288
# Iteration : 2000, Loss :  3.3534
# Iteration : 3000, Loss :  3.2080
# Iteration : 4000, Loss :  3.1960
# Iteration : 5000, Loss :  3.0625
# Iteration : 6000, Loss :  3.0487
# Iteration : 1000, Loss :  2.9731
# Iteration : 2000, Loss :  2.9392
# Iteration : 3000, Loss :  2.9480
# Iteration : 4000, Loss :  2.9099
# Iteration : 5000, Loss :  2.9089
# Iteration : 6000, Loss :  2.8805
# Iteration : 1000, Loss :  2.8546
# Iteration : 2000, Loss :  2.8494
# Iteration : 3000, Loss :  2.8539
# Iteration : 4000, Loss :  2.8372
# Iteration : 5000, Loss :  2.8148
# Iteration : 6000, Loss :  2.8089
# Iteration : 1000, Loss :  2.8223
# Iteration : 2000, Loss :  2.8251
# Iteration : 3000, Loss :  2.7836
# Iteration : 4000, Loss :  2.7778
# Iteration : 5000, Loss :  2.7783
# Iteration : 6000, Loss :  2.7704

# %%
attention.encoder.eval()
attention.decoder.eval()
# Out:
# AttentionDecoderLSTM(
#   (embedding): Embedding(5030, 512)
#   (drop_out): Dropout(p=0.2, inplace=False)
#   (lstm): LSTM(512, 512, num_layers=2)
#   (out): Linear(in_features=512, out_features=5030, bias=True)
# )

# %%
chat(attention.encoder, attention.decoder)
# Out:
# Let's chat (type 'bye' to exit)
# < 치매 를 예방 하 기 위해 는 한 생활 습관 을 유지 하 는 것 이 중요 합니다 . 치매 예방 을 위해 는 한 생활 습관 을 유지 하 는 것 이 중요 합니다 . 치매 예방 을 위해 는 한 한 생활 습관 을 유지 하 는 것 이 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 이 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 고 , 한 한 수면 을 취하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한 , 건강 한 식습관 을 유지 하 는 것 도 중요 합니다 . 또한
# < 치매 는 인지 기능 의 저하 로 인해 일상 생활 에 큰 영향 을 미치 는 질병 입니다 . 치매 는 치매 의 가장 흔한 원인 으로 알려져 있 으며 , 이 성 치매 는 뇌 의 의 손상 으로 인해 발생 합니다 . 치매 는 뇌 의 의 손상 으로 인해 발생 하 는 치매 의 , 혈관 성 치매 , 외상 , 뇌 등 의 치매 의 원인 으로 알려져 있 습니다 . 치매 는 치매 의 원인 흔한 원인 으로 알려져 있 으며 , 이 성 치매 는 뇌혈관 의 문제 로 인해 발생 하 는 치매 의 원인 이 . 치매 는 알츠하이머병 의 원인 으로 , 치매 의 원인 으로 알려져 있 습니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 알려져 있 으며 , 이 성 치매 는 뇌혈관 의 문제 로 인해 발생 하 는 치매 의 원인 이 될 수 있 습니다 . 치매 는 치매 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 으며 , 이 는 치매 의 원인 이 될 수 있 습니다 . 치매 는 치매 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 으며 , 이 는 치매 의 원인 이 될 수 있 습니다 . 치매 는 치매 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 으며 , 이 는 치매 의 원인 이 될 수 있 습니다 . 치매 는 알츠하이머병 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 으며 , 이 성 치매 는 뇌혈관 의 문제 로 인해 발생 하 는 치매 의 원인 이 될 수 있 습니다 . 치매 는 치매 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 으며 , 이 는 치매 의 원인 이 될 수 있 습니다 . 치매 는 치매 의 원인 으로 , 알츠하이머병
# < 알츠하이머병 은 치매 의 일으키 는 가장 흔한 퇴행 성 뇌 질환 입니다 . 알츠하이머병 은 뇌 의 의 손상 으로 인해 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 알츠하이머병 은 주로 의 의 저하 와 함께 인지 기능 의 저하 를 초래 합니다 . 알츠하이머병 은 주로 의 의 저하 와 함께 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 알츠하이머병 은 주로 의 의 저하 와 함께 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 은 치매 의 가장 흔한 형태 으로 , 알츠하이머병 은 의 손상 으로 인해 발생 합니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 은 치매 의 가장 흔한 형태 으로 , 알츠하이머병 은 의 손상 으로 인해 발생 합니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 은 치매 의 가장 흔한 형태 으로 , 알츠하이머병 은 의 손상 으로 인해 발생 합니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 은 치매 의 가장 흔한 형태 으로 , 알츠하이머병 은 의 손상 으로 인해 발생 합니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 은 치매 의 가장 흔한 형태 으로 , 알츠하이머병 은 의 손상 으로 인해 발생 합니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 은 치매 의 가장 흔한 형태 으로 , 알츠하이머병 은 의 손상 으로 인해 발생 합니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 은 치매 의 가장 흔한 형태 으로 , 알츠하이머병 은 의 손상 으로 인해 발생 합니다 .
# < 치매 는 진단 은 매우 중요 합니다 . 치매 의 초기 증상 을 확인 하 기 위해 는 한 검사 가 사용 됩니다 . mri 를 통해 치매 의 구조 와 기능 을 대한 상세 한 정보 를 얻 을 수 있 습니다 . 치매 의 초기 증상 을 확인 하 기 위해 는 한 검사 가 사용 됩니다 . mri 를 통해 치매 의 초기 치매 를 확인 할 수 있 습니다 . mri 를 통해 치매 의 초기 치매 진단 을 가능 성 을 확인 할 수 있 습니다 . mri 를 통해 치매 의 초기 치매 진단 을 가능 성 을 확인 할 수 있 습니다 . mri 를 통해 치매 의 초기 치매 진단 을 가능 성 을 높일 수 있 습니다 . mri 를 통해 치매 의 초기 치매 진단 을 가능 성 을 높일 수 있 습니다 .
# < 치매 는 노인 들 에게 주로 발생 하 는 치매 의 한 형태 로 , 치매 의 원인 으로 알려져 있 습니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 알려져 있 으며 , 뇌세포 의 손상 으로 인해 기억력 , 언어 능력 , 판단력 등 의 인지 기능 이 저하 되 는 것 으로 알려져 있 습니다 . 치매 의 주요 증상 은 는 기억력 저하 , 언어 능력 , 판단력 저하 , 시간 과 장소 혼동 , 성격 변화 , 우울증 등 의 증상 이 나타납니다 . 치매 의 증상 은 기억력 저하 와 함께 일상 생활 에 큰 영향 을 미치 며 , 이 는 치매 의 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 알려져 있 으며 , 이 성 치매 는 뇌혈관 의 문제 로 인해 발생 하 는 치매 의 원인 이 . 치매 는 치매 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 습니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 알려져 있 으며 , 이 성 치매 는 뇌혈관 의 문제 로 인해 발생 하 는 치매 의 원인 이 . 치매 는 치매 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 습니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 알려져 있 으며 , 이 성 치매 는 뇌혈관 의 문제 로 인해 발생 하 는 치매 의 원인 이 . 치매 는 치매 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 습니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 알려져 있 으며 , 이 성 치매 는 뇌혈관 의 문제 로 인해 발생 하 는 치매 의 원인 이 . 치매 는 치매 의 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 습니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 알려져 있 으며 ,
# < 치매 는 노인 들 사이 에서 흔히 나타나 는 질병 으로 , 초기 치매 의 진단 은 매우 중요 합니다 . 치매 의 초기 증상 을 확인 하 기 위해 는 한 검사 가 사용 됩니다 . mri 를 통해 초기 치매 의 징후 를 확인 할 수 있 습니다 . mri 를 통해 초기 치매 의 징후 를 파악 할 수 있 습니다 . mri 를 통해 초기 치매 의 징후 를 파악 할 수 있 습니다 . mri 를 통해 치매 의 초기 치매 의 징후 를 파악 할 수 있 습니다 . mri 를 통해 치매 의 초기 치매 의 징후 를 파악 할 수 있 습니다 . mri 를 통해 치매 의 조기 에 발견 하 고 적절 한 치료 와 관리 를 시작 할 수 있 습니다 .
# < 알츠하이머병 은 치매 를 일으키 는 가장 흔한 퇴행 성 뇌 질환 으로 , 주로 기억력 저하 와 인지 기능 의 저하 를 특징 으로 합니다 . 알츠하이머병 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 알츠하이머병 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 알츠하이머병 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 기억력 저하 와 인지 기능 의 저하 를 초래 합니다 . 이 질환 은 주로 의 이상 으로 인해 발생 하 며 , 이 로 인해 일상 생활 에 큰 영향 을 미치 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 으며 , 이 적 인 요인 과 환경 적 요인 이 복합 작용 하 여 발생 할 수 있 습니다 . 알츠하이머병 은 뇌 의 의 손상 과 인지 기능 의 저하 를 초래 하 는 , 으로 알려져 있 습니다 . 알츠하이머병 은 치매 의 가장 흔한 원인 으로 , 알츠하이머병 의 원인 으로 알려져 있 으며
